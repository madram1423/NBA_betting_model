# %%
def scheduled():
    try:
        # %run Unabated_scrape.ipynb
    except:
        print('error')

# %%
for i in range(9):
    scheduled()
    time.sleep(60*90)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7060\3263823425.py:10: DeprecationWarning: AppURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   opener = AppURLopener()
# 200
#        id        type                               attributes.image_url  \
# 0  142693  new_player                    https://i.imgur.com/uxUGj04.png
# 1  138032  new_player  https://s3-us-west-2.amazonaws.com/static.fant...
# 2   66721  new_player  https://s3-us-west-2.amazonaws.com/static.fant...
# 3  137936  new_player  https://s3-us-west-2.amazonaws.com/static.fant...
# 4   67816  new_player  https://static.prizepicks.com/images/players/m...
#
#   attributes.league  attributes.league_id attributes.market  \
# 0               MLB                   2.0              None
# 1            SOCCER                  82.0              None
# 2            SOCCER                  82.0              None
# 3            SOCCER                  82.0              None
# ...

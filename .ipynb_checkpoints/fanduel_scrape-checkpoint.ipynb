# %%
#imports and scraping raw data from site
#df is the actual betting line
#df2 has other info, mostly using to get player id to name dict

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import datetime as dt
import random
import re
from unidecode import unidecode
import time

# %%
import urllib3
import json
import urllib

# %%
today= dt.date.today()
pp_lines = pd.read_csv(f'Lines/full_lines{today.month}_{today.day}',index_col=0)
print('find these event ids')
pp_lines.loc[pp_lines.League==82].Team.unique()
# Out:
# find these event ids
# array(['Roma', 'Sevilla', 'Atlanta', 'New England', 'Toronto', 'Columbus',
#        'Chicago', 'Cincinnati', 'NYRB', 'Miami', 'Colorado', 'NYCFC',
#        'LAFC', 'Leon', 'Uruguay U20', 'Gambia U20'], dtype=object)

# %%
def scrape(url):
    #get raw json data from a single event api
    response = urllib.request.urlopen(url)
    print(response.status)
    return json.loads(response.read())

# %%
def process_data(data):
    #turn raw json data most of the way to a usable df
    path = data['attachments']['markets']
    b = pd.DataFrame()
    for k in list(path.keys()):
        a = pd.json_normalize(path[k],record_path ='runners')
        c =pd.json_normalize(path[k])
        for col in ['eventId','marketName','marketTime', 'marketType']:
            a[col] = c[col].values[0]
        b = pd.concat((b,a))
    return b

# %%
#have to find these by hand still
events = [32370875,32363138,32370922,32370168,32372098,]

lines = pd.DataFrame()
for i in range(len(events)):
    #get and transform data from multiple events
    id = events[i]
    fd_url = f'https://sbapi.nj.sportsbook.fanduel.com/api/event-page?_ak=FhMFpcPWXMeyZxOx&eventId={id}&tab=shots'
    try:
        data = scrape(fd_url)
        time.sleep(1)
        new = process_data(data)
        lines = pd.concat((lines,new))
    except:
        print(i,id,'error')
backup = lines.copy(deep=True)
    #seems like this is still overwriting the previous ones
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
#copying data for safety and grabbing relevant columns
#wrangling the strings to turn for example 'Player To Have 2 Or More Shots' into:
#handicap :1.5   and stat: Shots


g = backup[[ 'handicap', 'runnerName',
             'winRunnerOdds.americanDisplayOdds.americanOdds', 'eventId',
             'marketName', 'marketTime']].copy(deep=True)

g['handicap'] = g.marketName.apply(lambda x: x.split('Player To Have ')[-1].split(' ')[0])
g['marketName'] = g.marketName.apply(lambda x: ' '.join(x.split('Player To Have ')[-1].split(' ')[1:]).split('Or More ')[-1])

g.columns = ['Line', 'Player','Odds', 'eventId',
       'Stat', 'marketTime']

g = g.loc[g['Line'].str.match(r'^\d+$')]
g['Line'] = g['Line'].astype(float)
g['Line'] = g['Line'] - 0.5
g
# Out:
#     Line          Player   Odds   eventId                          Stat  \
# 0    0.5   Dante Vanzeir  -3000  32370875                         Shots
# 1    0.5  Josef Martinez  -1600  32370875                         Shots
# 2    0.5      Cory Burke  -1300  32370875                         Shots
# 3    0.5    Lewis Morgan  -1300  32370875                         Shots
# 4    0.5    Elias Manoel  -1100  32370875                         Shots
# ..   ...             ...    ...       ...                           ...
# 28   0.5   Raymon Gaddis  10000  32372098  Shots On Target in Each Half
# 29   0.5      Ian Murphy  10000  32372098  Shots On Target in Each Half
# 30   0.5  Thiago Martins  10000  32372098  Shots On Target in Each Half
# 31   0.5     Matt Miazga  10000  32372098  Shots On Target in Each Half
# 32   0.5     Tony Alfaro  10000  32372098  Shots On Target in Each Half
#
#                   marketTime
# 0   2023-05-31T23:30:00.000Z
# 1   2023-05-31T23:30:00.000Z
# 2   2023-05-31T23:30:00.000Z
# 3   2023-05-31T23:30:00.000Z
# 4   2023-05-31T23:30:00.000Z
# ..                       ...
# 28  2023-05-31T23:30:00.000Z
# 29  2023-05-31T23:30:00.000Z
# 30  2023-05-31T23:30:00.000Z
# 31  2023-05-31T23:30:00.000Z
# 32  2023-05-31T23:30:00.000Z
#
# [2981 rows x 6 columns]

# %%
x = pp_lines.merge(g).sort_values(by='Odds')
x
# Out:
#                   Player        Team  Line             Stat  League  \
# 27         Dante Vanzeir       Miami   1.5            Shots      82
# 28     Mark-Anthony Kaye     Chicago   0.5            Shots       6
# 16      Darlington Nagbe    Colorado   0.5            Shots      82
# 14       Cucho Hernandez    Colorado   4.5            Shots      82
# 15            Yaw Yeboah    Colorado   1.5            Shots      82
# 5          Oliver Torres        Roma   0.5            Shots      82
# 23         Kosi Thompson     Chicago   0.5            Shots      82
# 10       Lorenzo Insigne     Chicago   2.5            Shots      82
# 31    Santiago Rodriguez  Cincinnati   1.5            Shots      82
# 26        Malte Amundsen    Colorado   0.5            Shots      82
# 30    Santiago Rodriguez  Cincinnati   0.5  Shots On Target      82
# 6    Leonardo Spinazzola     Sevilla   0.5            Shots      82
# 29          Talles Magno  Cincinnati   1.5            Shots      82
# 12         Richie Laryea     Chicago   0.5            Shots      82
# 22            Yaw Yeboah    Colorado   0.5  Shots On Target      82
# 13        Rafael Czichos     Toronto   0.5            Shots      82
# 11          Dixon Arroyo        NYRB   0.5            Shots      82
# 3      Youssef En-Nesyri        Roma   2.5            Shots      82
# 21       Dominique Badji       NYCFC   1.5            Shots      82
# 2          Lucas Ocampos        Roma   0.5  Shots On Target      82
# 18  Maren Haile-Selassie     Toronto   0.5  Shots On Target      82
# 19         Junior Moreno       NYCFC   0.5            Shots      82
# 4       Gianluca Mancini     Sevilla   0.5            Shots      82
# 20        Gaston Gimenez     Toronto   0.5            Shots      82
# 8           Ivan Rakitic        Roma   1.5            Shots      82
# 24  Maren Haile-Selassie     Toronto   1.5            Shots      82
# 0     Lorenzo Pellegrini     Sevilla   0.5  Shots On Target      82
# 1          Nemanja Matic     Sevilla   0.5            Shots      82
# 9            Sean Nealis       Miami   0.5            Shots      82
# 1        Nemanja Matic  Sevilla   0.5            Shots      82  2023-05-31
#
#    Odds   eventId                marketTime
# 6  -180  32363138  2023-05-31T19:00:00.000Z
# 4  -125  32363138  2023-05-31T19:00:00.000Z
# 0   115  32363138  2023-05-31T19:00:00.000Z
# 1   140  32363138  2023-05-31T19:00:00.000Z

# %%
x.loc[x.Team=='Roma']
# Out:
#               Player  Team  Line             Stat  League        Date  Odds  \
# 5      Oliver Torres  Roma   0.5            Shots      82  2023-05-31  -280
# 3  Youssef En-Nesyri  Roma   2.5            Shots      82  2023-05-31  -145
# 2      Lucas Ocampos  Roma   0.5  Shots On Target      82  2023-05-31  -130
# 8       Ivan Rakitic  Roma   1.5            Shots      82  2023-05-31  -105
# 7       Ivan Rakitic  Roma   0.5  Shots On Target      82  2023-05-31   160
#
#     eventId                marketTime
# 5  32363138  2023-05-31T19:00:00.000Z
# 3  32363138  2023-05-31T19:00:00.000Z
# 2  32363138  2023-05-31T19:00:00.000Z
# 8  32363138  2023-05-31T19:00:00.000Z
# 7  32363138  2023-05-31T19:00:00.000Z

# %%
dk = scrape('https://sportsbook.draftkings.com//sites/US-SB/api/v5/eventgroups/89345/categories/1113?format=json')
# Out:
# 200

# %%
pd.json_normalize(dk['eventGroup'])
# Out:
#   eventGroupId displayGroupId       name  \
# 0        89345              1  USA - MLS
#
#                                      offerCategories  \
# 0  [{'offerCategoryId': 490, 'name': 'Game Lines'...
#
#                                               events  \
# 0  [{'eventId': '28937911', 'displayGroupId': '1'...
#
#                                                 tags nameIdentifier
# 0  [MatchTracker, PrePack, Scoreboard, SportcastB...      USA - MLS

# %%
dk2 = pd.json_normalize(dk['eventGroup']['offerCategories'][2]['offerSubcategoryDescriptors'])
dk2
# Out:
#    subcategoryId                        name   offerSubcategory.name  \
# 0          11004      Player Shots on Target  Player Shots on Target
# 1          11005                Player Shots                     NaN
# 2          11006              Player Assists                     NaN
# 3          12377  Shot on Target - Each Half                     NaN
#
#    offerSubcategory.subcategoryId  offerSubcategory.componentId  \
# 0                         11004.0                          29.0
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
#
#                              offerSubcategory.offers
# 0  [[{'providerOfferId': '149783886', 'eventId': ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN

# %%
pd.json_normalize(dk2['offerSubcategory.offers'][0][0][0])
# Out:
#   providerOfferId   eventId eventGroupId  \
# 0       149783886  28937911        89345
#
#                                       label  isSuspended  isOpen  \
# 0  Player to Have 1 or More Shots on Target        False    True
#
#    offerSubcategoryId  isSubcategoryFeatured  betOfferTypeId  \
# 0               11004                   True               0
#
#   providerCriterionId                                           outcomes  \
# 0               10065  [{'providerOutcomeId': '0QA149783886#152841609...
#
#   offerUpdateState  offerSequence source displayGroupId   main
# 0                0              1      3              1  False

# %%
#imports and scraping raw data from site
#df is the actual betting line
#df2 has other info, mostly using to get player id to name dict
from scipy.stats import poisson
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import datetime as dt
import random
import time
#time.sleep(2.5*60*60)

# %run functions.ipynb
# %run underdog_scrape.ipynb
# %run pp_scrape.ipynb
# %run parlayplay.ipynb
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\3263823425.py:10: DeprecationWarning: AppURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   opener = AppURLopener()
# 200
#        id        type                               attributes.image_url  \
# 0   47808  new_player  https://s3-us-west-2.amazonaws.com/static.fant...
# 1   48151  new_player  https://s3-us-west-2.amazonaws.com/static.fant...
# 2  127204  new_player  https://static.prizepicks.com/images/players/m...
# 3   64524  new_player  https://static.prizepicks.com/images/players/g...
# 4   70978  new_player  https://s3-us-west-2.amazonaws.com/static.fant...
#
#   attributes.league  attributes.league_id attributes.market  \
# 0            SOCCER                  82.0              None
# 1            SOCCER                  82.0              None
# 2               MLB                   2.0         San Diego
# 3               PGA                   1.0
# 4            SOCCER                  82.0              None
#
#      attributes.name attributes.position attributes.team attributes.team_name  \
# 0   Domenico Berardi                   M        Sassuolo                 None
# 1  Frédéric Guilbert                   M      Strasbourg                 None
# 2    Xander Bogaerts                  IF              SD               Padres
# 3      Jordan Spieth                   G        J.Spieth
# 4     Janis Blaswich                  GK      RB Leipzig                 None
#
#   relationships.league.data.id relationships.league.data.type  \
# 0                           82                         league
# 1                           82                         league
# 2                            2                         league
# 3                            1                         league
# 4                           82                         league
#
#   attributes.lfg_ignored_leagues attributes.active attributes.icon  \
# 0                            NaN               NaN             NaN
# 1                            NaN               NaN             NaN
# 2                            NaN               NaN             NaN
# 3                            NaN               NaN             NaN
# 4                            NaN               NaN             NaN
#
#   attributes.last_five_games_enabled  attributes.projections_count  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    attributes.rank relationships.projection_filters.data
# 0              NaN                                   NaN
# 1              NaN                                   NaN
# 2              NaN                                   NaN
# 3              NaN                                   NaN
# 4              NaN                                   NaN
# 930
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\2042246692.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player'] = df['relationships.new_player.data.id'].map(names_dict)
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\2753160774.py:10: DeprecationWarning: AppURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   opener = AppURLopener()
# 200
# C:\Users\User\AppData\Local\Temp\ipykernel_8156\1129872439.py:10: DeprecationWarning: AppURLopener style of invoking requests is deprecated. Use newer urlopen functions/methods
#   opener = AppURLopener()
# 200

# %%
#scraping data
import urllib3
import json
import gzip

import urllib
class AppURLopener(urllib.request.FancyURLopener):
    version = "Mozilla/5.0"

    

unabated_url = 'https://content.unabated.com/markets/b_playerprops.json?uuid=45370775-9550-48cf-be97-ed8cbe57db0d'
#dog_props_url = 'https://unabated.com/nba/props'
response = opener.open(unabated_url)

http = urllib3.PoolManager()

url = 'https://httpbin.org/post'
myheaders = {'Content-Type': 'application/json'}
mydata = {'username': '***', 'password': '***'}
print(response.status)
decoded_content = gzip.decompress(response.read())
data = json.loads(decoded_content)
# Out:
# 200

# %%
#team from id dict
teamtemp = pd.json_normalize(data['teams'],max_level=0)
teams = pd.DataFrame()
for i in range(len(teamtemp.T)):
    teams = pd.concat((teams,pd.json_normalize(teamtemp.iloc[0,i])))
teams = teams[['abbreviation','id']]
teamdict = dict(zip(teams.id,teams.abbreviation))

# %%
#bookie from id dict
bookies = pd.json_normalize(data['marketSources'])
bookies
id2book = dict(list(zip(bookies.id,bookies.name)))
id2book[13]
# Out:
# '888sports'

# %%
#player json normalize
people = pd.json_normalize(data['people'],max_level=0)
ppl = pd.DataFrame()
for i in range(len(people.T)):
    y = pd.json_normalize(people.T.iloc[i])
    ppl = pd.concat((ppl,y))
ppl.sample(3)
# Out:
#              headshotUrl firstName  lastName preferredName jerseyNumber  \
# 0   players/mlb/5774.png     Jesús   Luzardo         Jesús           44
# 0  players/mlb/42123.png   Anthony     Rizzo       Anthony           48
# 0  players/mlb/41266.png      Jack  Suwinski          Jack           65
#
#   country  height  weight position                  birthDate  leagueId  \
# 0     PER      72     218        P  1997-09-30T00:00:00+00:00         5
# 0     USA      75     240       IF  1989-08-08T00:00:00+00:00         5
# 0     USA      74     215       OF  1998-07-29T00:00:00+00:00         5
#
#                     createdOn createdBy                  modifiedOn  \
# 0  2022-09-11T03:22:33.878324       -28  2023-05-26T00:00:13.276314
# 0  2022-09-11T03:42:17.353276       -28   2023-05-26T00:00:12.86215
# 0  2022-09-11T03:42:07.425132       -28  2023-05-26T00:00:10.859493
#
#   modifiedBy     id
# 0        -28   5774
# 0        -28  42123
# 0        -28  41266

# %%
i2p = dict(zip(ppl.id,(ppl.firstName+' '+ppl.lastName)))

# %%
#step 1 of json normalize for lines
df = pd.json_normalize(data['propsPeopleEvents'],max_level=0)
df2 = pd.json_normalize(df.iloc[0,0])

df2 = pd.DataFrame()
for i in range(len(df.columns)):
    df_temp = pd.json_normalize(df.iloc[0,i],max_level=0)
    df2 = pd.concat((df2,df_temp)).reset_index(drop=True)
df2.playerPosition.unique()
# Out:
# array(['OF', 'IF', 'C', 'P', 'DH', 'G-F', 'C-F', 'F', 'F-C', 'G', 'F-G'],
#       dtype=object)

# %%
#replace player id with name
df2.personId = df2.personId.apply(lambda x: i2p[x])

# %%
#replacing team id with team name
teams = pd.json_normalize(df2.eventTeams)
teams[['1.id','0.id']]
teams['Team'] =teams['0.id'].apply(lambda x: teamdict[x])
teams['Opp'] =teams['1.id'].apply(lambda x: teamdict[x])
teams = teams[['Team','Opp']]
teams['Opp'][0]
# Out:
# 'TB'

# %%
teams
# Out:
#     Team  Opp
# 0    LAD   TB
# 1    LAD   TB
# 2    LAD   TB
# 3    LAD   TB
# 4    LAD   TB
# ..   ...  ...
# 311  BOS  MIA
# 312  BOS  MIA
# 313  BOS  MIA
# 314  BOS  MIA
# 315  BOS  MIA
#
# [316 rows x 2 columns]

# %%
#renaming stats
bt2stat = {'bt77': 'TRB',
          'bt73': 'PTS',
          'bt69': '3P',
          'bt78': 'TRB+AST',
          'bt74': 'PTS+AST',
          'bt75': 'PTS+TRB',
           'bt76': 'PTS+TRB+AST',
           'bt70': 'AST',
           'bt84': 'TO',
           'bt82': 'BLK+STL',
           'bt81': 'STL',
           'bt71': 'BLK',
           'bt72': 'Techs',
          'bt83': 'Triple Double',
           'bt77': 'TRB',
          'bt73': 'PTS',
          'bt69': '3P',
          'bt78': 'TRB + AST',
          'bt74': 'PTS+AST',
          'bt75': 'PTS+TRB',
           'bt76': 'PTS+TRB+AST',
           'bt70': 'AST',
           'bt84': 'TO',
           'bt82': 'BLK + STL',
           'bt81': 'STL',
           'bt71': 'BLK',
           'bt72': 'Techs',
          'bt83': 'Triple Double',
          'bt85': 'Total Hits',
          'bt19': 'Total Bases',
          'bt17': 'Pitcher Strikeouts',
          'bt18': 'Home Runs'}

# %%
df2['propsMarketSourcesLines'][0].keys()
# Out:
# dict_keys(['si0:ms31:an0', 'si0:ms2:an0', 'si0:ms1:an0', 'si0:ms4:an0', 'si0:ms20:an0', 'si0:ms27:an0', 'si0:ms17:an0', 'si0:ms30:an0', 'si1:ms20:an0', 'si1:ms1:an0', 'si1:ms4:an0', 'si1:ms27:an0', 'si1:ms17:an0', 'si1:ms31:an0', 'si1:ms30:an0'])

# %%
#%%timeit

#func to further normalize and aggregate lines for each player
#biggest bottleneck speed wise
def get_odds(row):
    player_name = df2.personId[row]
    guy_base = df2['propsMarketSourcesLines'][row].keys()
    luka = df2['propsMarketSourcesLines'][row]
    test_list = []
    for k in guy_base:
        for k2 in luka[k]:
            new = pd.json_normalize(luka[k][k2])
            new['k'] = k
            book = k.split(':')[1][2:]
            book_name = id2book.get(int(book), 'idk')
            new['book'] = np.where(book_name == 'idk', 'idk', book_name)
            new['side'] = np.where(k.split(':')[0] == 'si0', 'over', 'under')
            new['stat'] = bt2stat.get(k2, k2)
            test_list.append(new)
    test = pd.concat(test_list, axis=0)
    test['player'] = player_name
    test = test[['player','points','price','side','stat','book']].dropna()
    test['Prob'] = test['price'].apply(lambda x: (-x/(100-x)) if x < 0 else 100/(x+100))
    test['Opp'] = teams['Opp'][row]
    test['Team'] = teams['Team'][row]
    return test
luka = get_odds(0)
luka.head()
# Out:
#          player  points  price  side         stat     book      Prob Opp Team
# 0  James Outman     0.5    540  over    Home Runs   Unibet  0.156250  TB  LAD
# 0  James Outman     0.5   -125  over   Total Hits   Unibet  0.555556  TB  LAD
# 0  James Outman     1.5    185  over  Total Bases   Unibet  0.350877  TB  LAD
# 0  James Outman     0.5    520  over    Home Runs  FanDuel  0.161290  TB  LAD
# 0  James Outman     0.5   -150  over   Total Hits  FanDuel  0.600000  TB  LAD

# %%
#getting lines for every player
odds = pd.DataFrame()
for i in range(len(df2)):
    if i % 20==0:
        print(i,'/',len(df2))
    odds = pd.concat((odds,get_odds(i)))
odds.sample(3)
# Out:
# 0 / 316
# 20 / 316
# 40 / 316
# 60 / 316
# 80 / 316
# 100 / 316
# 120 / 316
# 140 / 316
# 160 / 316
# 180 / 316
# 200 / 316
# 220 / 316
# 240 / 316
# 260 / 316
# 280 / 316
# 300 / 316
#               player  points price   side         stat        book      Prob  \
# 0  Anthony Santander     1.5  -167  under  Total Bases      Unibet  0.625468
# 0  Christopher Morel     0.5  -130   over   Total Hits   PointsBet  0.565217
# 0         Jonah Heim     0.5   600   over    Home Runs  TwinSpires  0.142857
#
#    Opp Team
# 0  BAL  TEX
# 0  CHC  CIN
# 0  BAL  TEX

# %%
odds.to_csv('Lines/unabated')
odds.sample(2)
# Out:
#              player  points price   side         stat        book      Prob  \
# 0         Alec Bohm     1.5  -177  under  Total Bases  TwinSpires  0.638989
# 0  Gunnar Henderson     0.5   800   over    Home Runs  TwinSpires  0.111111
#
#    Opp Team
# 0  ATL  PHI
# 0  BAL  TEX

# %%
#bookmaker is broken right now
#not sure how to handle Total Bases because it isn't poisson
odds = odds.loc[odds.book !='Bookmaker']
odds = odds.loc[~((odds.stat =='Total Bases') & (odds.points==1.5))]
len(odds)
# Out:
# 9058

# %%
#getting probabilities to hit every posted line for every player
#probably could use more optimization

columns=['Player','Stat','Line','o_Prob','u_Prob','num_books','means']
players = odds.player.unique()
#players = ['Aaron Gordon']
fullpdf = pd.DataFrame()
for p in players:
    trae = odds.loc[odds.player==p]
    for stat in trae.stat.unique():
        tstat = trae.loc[trae.stat==stat]
        temp = []
        for points in tstat.points.unique():
            tstatline = tstat.loc[tstat.points==points]
            overprob = tstatline.loc[tstatline.side=='over'].Prob.mean()
            underprob = tstatline.loc[tstatline.side=='under'].Prob.mean()
            num_books = len(tstatline)/2
            trueover = (overprob/(overprob+underprob))
            trueunder = (underprob/(overprob+underprob))
            avg = prob2mean(trueover,points,'over')
            temp.append([p,stat,points,round(trueover,2),round(trueunder,2),num_books,avg])
        pdf = pd.DataFrame(temp,columns=columns)
        avg = sum((pdf.means * pdf.num_books))/pdf.num_books.sum()
        pdf['means'] = avg
        pdf.o_Prob=pdf.apply(lambda row: mean2prob(row['means'], row['Line'], 'over'), axis=1)
        pdf.u_Prob=pdf.apply(lambda row: mean2prob(row['means'], row['Line'], 'under'), axis=1)
        fullpdf = pd.concat((fullpdf,pdf))

fullpdf
# Out:
#           Player           Stat  Line    o_Prob    u_Prob  num_books  \
# 0   James Outman      Home Runs   0.5  0.154899  0.845101        7.0
# 0   James Outman     Total Hits   0.5  0.519959  0.480041        7.5
# 0   James Outman    Total Bases   0.5  0.518212  0.481788        3.0
# 0      Jose Siri      Home Runs   0.5  0.129892  0.870108        4.0
# 0      Jose Siri     Total Hits   0.5  0.549729  0.450271        4.5
# ..           ...            ...   ...       ...       ...        ...
# 0   Jimmy Butler      BLK + STL   2.5  0.513930  0.486070        4.0
# 0   Jimmy Butler    PTS+TRB+AST  42.5  0.506861  0.493139        9.0
# 0   Jimmy Butler             3P   0.5  0.588551  0.411449        5.0
# 0   Jimmy Butler          Techs   0.5  0.303744  0.696256        3.0
# 0   Jimmy Butler  Triple Double   0.5  0.045824  0.954176        1.0
#
#         means
# 0    0.168299
# 0    0.733884
# 0    0.730251
# 0    0.139138
# 0    0.797905
# ..        ...
# 0    2.730966
# 0   42.779499
# 0    0.888069
# 0    0.362038
# 0    0.046907
#
# [955 rows x 7 columns]

# %%
fullpdf = fullpdf.reset_index(drop=True)
fullpdf.to_csv('Lines/fullpdf')
fullpdf
# Out:
#            Player           Stat  Line    o_Prob    u_Prob  num_books  \
# 0    James Outman      Home Runs   0.5  0.154899  0.845101        7.0
# 1    James Outman     Total Hits   0.5  0.519959  0.480041        7.5
# 2    James Outman    Total Bases   0.5  0.518212  0.481788        3.0
# 3       Jose Siri      Home Runs   0.5  0.129892  0.870108        4.0
# 4       Jose Siri     Total Hits   0.5  0.549729  0.450271        4.5
# ..            ...            ...   ...       ...       ...        ...
# 950  Jimmy Butler      BLK + STL   2.5  0.513930  0.486070        4.0
# 951  Jimmy Butler    PTS+TRB+AST  42.5  0.506861  0.493139        9.0
# 952  Jimmy Butler             3P   0.5  0.588551  0.411449        5.0
# 953  Jimmy Butler          Techs   0.5  0.303744  0.696256        3.0
# 954  Jimmy Butler  Triple Double   0.5  0.045824  0.954176        1.0
#
#          means
# 0     0.168299
# 1     0.733884
# 2     0.730251
# 3     0.139138
# 4     0.797905
# ..         ...
# 950   2.730966
# 951  42.779499
# 952   0.888069
# 953   0.362038
# 954   0.046907
#
# [955 rows x 7 columns]

# %%
#getting fantasy site lines
#removing weird lines like series, half of quarter
pp_lines = pd.read_csv(f'Lines/full_lines{today.month}_{today.day}',index_col=0)
dog_lines = pd.read_csv(f'Lines/doglines{today.month}_{today.day}',index_col=0)
pp_lines = pp_lines.loc[~pp_lines['League'].isin([250,84,251,231,192,193,227])]
parlay = pd.read_csv(f'Lines/parlaylines{today.month}_{today.day}',index_col=0)

# %%
dog_lines.League.unique()
# Out:
# array(['MLB', 'other', 'NBA', 'WNBA', 'SOCCER', 'ESPORTS', 'RACING'],
#       dtype=object)

# %%
pp_lines
# Out:
#                   Player        Team    Line          Stat  League        Date
# 0           Nikola Jokic         TBA    27.5           PTS       7  2023-06-01
# 1         Bijan Robinson    2023 ATL  1075.5    Rush Yards     163  2023-09-07
# 2            Bryce Young    2023 CAR  3649.5    Pass Yards     163  2023-09-07
# 3          Hunter Greene         CHC     4.0  Hits Allowed       2  2023-05-26
# 4     Christopher Nkunku  Schalke 04     0.5         Goals      82  2023-05-27
# ...                  ...         ...     ...           ...     ...         ...
# 1766      Miro Heiskanen         VGK     1.5          Hits       8  2023-05-27
# 1767      Brayden McNabb         DAL     1.5          Hits       8  2023-05-27
# 1768       Ty Dellandrea         VGK     2.0          Hits       8  2023-05-27
# 1769      Ivan Barbashev         DAL     3.5          Hits       8  2023-05-27
# 1770         Roope Hintz         VGK     2.0          Hits       8  2023-05-27
#
# [1666 rows x 6 columns]

# %%
dog_lines
# Out:
#       Line                  Stat            Player  League  \
# 0      7.0    Pitcher Strikeouts     Hunter Greene     MLB
# 1    100.5           pitch_count     Hunter Greene     MLB
# 2      7.5  Hitter Fantasy Score    Jonathan India     MLB
# 3      0.5               Singles     Spencer Steer     MLB
# 4      0.5               Singles  Tyler Stephenson     MLB
# ..     ...                   ...               ...     ...
# 814   11.5              position       Alex Bowman  RACING
# 815   10.5              position     Kevin Harvick  RACING
# 816   12.5              position       Joey Logano  RACING
# 817   11.5              position       Ryan Blaney  RACING
# 818   14.5              position     Daniel Suarez  RACING
#
#                                      Team        Date
# 0                                     CIN  2023-05-26
# 1                                     CIN  2023-05-26
# 2                                     CIN  2023-05-26
# 3                                     CIN  2023-05-26
# 4                                     CIN  2023-05-26
# ..                                    ...         ...
# 814  01931c15-319d-4425-af04-209235a65c8d         NaN
# 815  613c00bc-da7e-4b7b-8ed9-dc32c2eccd95         NaN
# 816  d3fd26b6-20d3-47c1-98ee-b67ea5870d43         NaN
# 817  99bfb686-6910-4652-b064-69d19d62d31b         NaN
# 818  5d927a11-3b03-451d-b669-48670c7673f9         NaN
#
# [819 rows x 6 columns]

# %%
fullpdf
# Out:
#            Player           Stat  Line    o_Prob    u_Prob  num_books  \
# 0    James Outman      Home Runs   0.5  0.154899  0.845101        7.0
# 1    James Outman     Total Hits   0.5  0.519959  0.480041        7.5
# 2    James Outman    Total Bases   0.5  0.518212  0.481788        3.0
# 3       Jose Siri      Home Runs   0.5  0.129892  0.870108        4.0
# 4       Jose Siri     Total Hits   0.5  0.549729  0.450271        4.5
# ..            ...            ...   ...       ...       ...        ...
# 950  Jimmy Butler      BLK + STL   2.5  0.513930  0.486070        4.0
# 951  Jimmy Butler    PTS+TRB+AST  42.5  0.506861  0.493139        9.0
# 952  Jimmy Butler             3P   0.5  0.588551  0.411449        5.0
# 953  Jimmy Butler          Techs   0.5  0.303744  0.696256        3.0
# 954  Jimmy Butler  Triple Double   0.5  0.045824  0.954176        1.0
#
#          means
# 0     0.168299
# 1     0.733884
# 2     0.730251
# 3     0.139138
# 4     0.797905
# ..         ...
# 950   2.730966
# 951  42.779499
# 952   0.888069
# 953   0.362038
# 954   0.046907
#
# [955 rows x 7 columns]

# %%
#finding where prizepicks and underdog are different
fantasy = pp_lines.merge(dog_lines, on=['Player','Stat','Date'],how='inner',suffixes=('_pp','_dog'))
fantasy['difference'] = ((fantasy['Line_pp'] - fantasy['Line_dog']))/fantasy['Line_pp']
fantasy = fantasy.sort_values(by='difference')
fantasy.sample(3)
# Out:
#             Player                         Team_pp  Line_pp  \
# 148    Jewell Loyd                             DAL     21.5
# 25   Justin Steele                             CIN      5.5
# 117        MrFaliN  Natus Vincere (MAPS 1-2 Kills)     26.5
#
#                    Stat  League_pp        Date  Line_dog League_dog  \
# 148                 PTS          3  2023-05-26      21.5       WNBA
# 25   Pitcher Strikeouts          2  2023-05-26       5.5        MLB
# 117      MAPS 1-2 Kills        159  2023-05-26      24.0    ESPORTS
#
#          Team_dog  difference
# 148           SEA     0.00000
# 25            CHC     0.00000
# 117   FUT Esports     0.09434

# %%
temp = fantasy.loc[(fantasy['difference'] != 0.0)]
temp = temp.loc[temp.Stat != 'Hitter Fantasy Score'].sort_values(by='difference')
temp = temp[['Player','Line_pp','Line_dog','Stat', 'difference',  'Date',
       'League_dog', 'Team_dog' ]]
temp.to_csv(f'bets/fantasy_bets_{str(today)}.csv')

# %%
temp.loc[temp.Stat != 'Hitter Fantasy Score']
# Out:
#                 Player  Line_pp  Line_dog            Stat  difference  \
# 42       Marina Mabrey      3.5       4.0             AST   -0.142857
# 126           cauanzin     29.0      31.5  MAPS 1-2 Kills   -0.086207
# 98          Al Horford      7.0       7.5             PTS   -0.071429
# 99          Al Horford     15.5      16.5     PTS+TRB+AST   -0.064516
# 46         Bam Adebayo     12.0      12.5         TRB+AST   -0.041667
# 199             TA2000     16.5      17.0  MAPS 1-2 Kills   -0.030303
# 213            Queenix     33.5      34.5  MAPS 1-2 Kills   -0.029851
# 44         Bam Adebayo     20.5      21.0         PTS+AST   -0.024390
# 130               tuyz     24.5      25.0  MAPS 1-2 Kills   -0.020408
# 142            Zellsis     27.0      27.5  MAPS 1-2 Kills   -0.018519
# 208         NickelBack     32.5      33.0  MAPS 1-2 Kills   -0.015385
# 123              aspas     38.0      38.5  MAPS 1-2 Kills   -0.013158
# 7         Jayson Tatum     47.0      46.5     PTS+TRB+AST    0.010638
# 205             Woro2k     39.0      38.5  MAPS 1-2 Kills    0.012821
# 118               cNed     36.5      36.0  MAPS 1-2 Kills    0.013699
# 214            salazar     34.0      33.5  MAPS 1-2 Kills    0.014706
# 120           SUYGETSU     32.5      32.0  MAPS 1-2 Kills    0.015385
# 132            Boostio     31.5      31.0  MAPS 1-2 Kills    0.015873
# 70   Courtney Williams     21.0      20.5     PTS+TRB+AST    0.023810
# 209               deko     41.0      40.0  MAPS 1-2 Kills    0.024390
# 212            kraghen     36.0      35.0  MAPS 1-2 Kills    0.027778
# 121             Zyppan     30.5      29.5  MAPS 1-2 Kills    0.032787
# 211             tabseN     37.5      36.0  MAPS 1-2 Kills    0.040000
# 207           Forester     37.0      35.5  MAPS 1-2 Kills    0.040541
# 106                qw1     34.5      33.0  MAPS 1-2 Kills    0.043478
# 77           Max Strus     11.0      10.5             PTS    0.045455
# 107              qRaxs     29.5      28.0  MAPS 1-2 Kills    0.050847
# 141              jakee     28.5      27.0  MAPS 1-2 Kills    0.052632
# 135            jawgemo     28.5      27.0  MAPS 1-2 Kills    0.052632
# 134                C0M     25.0      23.5  MAPS 1-2 Kills    0.060000
# 117            MrFaliN     26.5      24.0  MAPS 1-2 Kills    0.094340
# 116          AtaKaptan     27.0      24.0  MAPS 1-2 Kills    0.111111
# 204             Gunnar     12.5      11.0  MAPS 1-2 Kills    0.120000
# 200              No!ob     16.0      14.0  MAPS 1-2 Kills    0.125000
# 203             Yamsun     11.0       9.5  MAPS 1-2 Kills    0.136364
# 114   Domenico Berardi      3.5       3.0           Shots    0.142857
# 113    Andrea Consigli      2.5       2.0    Goalie Saves    0.200000
#
#            Date League_dog        Team_dog
# 42   2023-05-26       WNBA             CHI
# 126  2023-05-26    ESPORTS           LOUD
# 98   2023-05-27        NBA             BOS
# 99   2023-05-27        NBA             BOS
# 46   2023-05-27        NBA             MIA
# 199  2023-05-26    ESPORTS           Quest
# 213  2023-05-26    ESPORTS        ECSTATIC
# 44   2023-05-27        NBA             MIA
# 130  2023-05-26    ESPORTS           LOUD
# 142  2023-05-26    ESPORTS         Cloud9
# 208  2023-05-26    ESPORTS           1WIN
# 123  2023-05-26    ESPORTS           LOUD
# 7    2023-05-27        NBA             BOS
# 205  2023-05-26    ESPORTS           Monte
# 118  2023-05-26    ESPORTS  Natus Vincere
# 214  2023-05-26    ESPORTS        ECSTATIC
# 120  2023-05-26    ESPORTS  Natus Vincere
# 132  2023-05-26    ESPORTS   Evil Geniuses
# 70   2023-05-26       WNBA             CHI
# 209  2023-05-26    ESPORTS           1WIN
# 212  2023-05-26    ESPORTS        ECSTATIC
# 121  2023-05-26    ESPORTS  Natus Vincere
# 211  2023-05-26    ESPORTS            BIG
# 207  2023-05-26    ESPORTS           1WIN
# 106  2023-05-26    ESPORTS     FUT Esports
# 77   2023-05-27        NBA             MIA
# 107  2023-05-26    ESPORTS     FUT Esports
# 141  2023-05-26    ESPORTS         Cloud9
# 135  2023-05-26    ESPORTS   Evil Geniuses
# 134  2023-05-26    ESPORTS   Evil Geniuses
# 117  2023-05-26    ESPORTS     FUT Esports
# 116  2023-05-26    ESPORTS     FUT Esports
# 204  2023-05-26    ESPORTS           nouns
# 200  2023-05-26    ESPORTS           Quest
# 203  2023-05-26    ESPORTS           nouns
# 114  2023-05-26     SOCCER        Sassuolo
# 113  2023-05-26     SOCCER        Sassuolo

# %%
temp.loc[temp.League_dog == 'ESPORTS']
# Out:
#          Player  Line_pp  Line_dog            Stat  difference        Date  \
# 126    cauanzin     29.0      31.5  MAPS 1-2 Kills   -0.086207  2023-05-26
# 199      TA2000     16.5      17.0  MAPS 1-2 Kills   -0.030303  2023-05-26
# 213     Queenix     33.5      34.5  MAPS 1-2 Kills   -0.029851  2023-05-26
# 130        tuyz     24.5      25.0  MAPS 1-2 Kills   -0.020408  2023-05-26
# 142     Zellsis     27.0      27.5  MAPS 1-2 Kills   -0.018519  2023-05-26
# 208  NickelBack     32.5      33.0  MAPS 1-2 Kills   -0.015385  2023-05-26
# 123       aspas     38.0      38.5  MAPS 1-2 Kills   -0.013158  2023-05-26
# 205      Woro2k     39.0      38.5  MAPS 1-2 Kills    0.012821  2023-05-26
# 118        cNed     36.5      36.0  MAPS 1-2 Kills    0.013699  2023-05-26
# 214     salazar     34.0      33.5  MAPS 1-2 Kills    0.014706  2023-05-26
# 120    SUYGETSU     32.5      32.0  MAPS 1-2 Kills    0.015385  2023-05-26
# 132     Boostio     31.5      31.0  MAPS 1-2 Kills    0.015873  2023-05-26
# 209        deko     41.0      40.0  MAPS 1-2 Kills    0.024390  2023-05-26
# 212     kraghen     36.0      35.0  MAPS 1-2 Kills    0.027778  2023-05-26
# 121      Zyppan     30.5      29.5  MAPS 1-2 Kills    0.032787  2023-05-26
# 211      tabseN     37.5      36.0  MAPS 1-2 Kills    0.040000  2023-05-26
# 207    Forester     37.0      35.5  MAPS 1-2 Kills    0.040541  2023-05-26
# 106         qw1     34.5      33.0  MAPS 1-2 Kills    0.043478  2023-05-26
# 107       qRaxs     29.5      28.0  MAPS 1-2 Kills    0.050847  2023-05-26
# 141       jakee     28.5      27.0  MAPS 1-2 Kills    0.052632  2023-05-26
# 135     jawgemo     28.5      27.0  MAPS 1-2 Kills    0.052632  2023-05-26
# 134         C0M     25.0      23.5  MAPS 1-2 Kills    0.060000  2023-05-26
# 117     MrFaliN     26.5      24.0  MAPS 1-2 Kills    0.094340  2023-05-26
# 116   AtaKaptan     27.0      24.0  MAPS 1-2 Kills    0.111111  2023-05-26
# 204      Gunnar     12.5      11.0  MAPS 1-2 Kills    0.120000  2023-05-26
# 200       No!ob     16.0      14.0  MAPS 1-2 Kills    0.125000  2023-05-26
# 203      Yamsun     11.0       9.5  MAPS 1-2 Kills    0.136364  2023-05-26
#
#     League_dog        Team_dog
# 126    ESPORTS           LOUD
# 199    ESPORTS           Quest
# 213    ESPORTS        ECSTATIC
# 130    ESPORTS           LOUD
# 142    ESPORTS         Cloud9
# 208    ESPORTS           1WIN
# 123    ESPORTS           LOUD
# 205    ESPORTS           Monte
# 118    ESPORTS  Natus Vincere
# 214    ESPORTS        ECSTATIC
# 120    ESPORTS  Natus Vincere
# 132    ESPORTS   Evil Geniuses
# 209    ESPORTS           1WIN
# 212    ESPORTS        ECSTATIC
# 121    ESPORTS  Natus Vincere
# 211    ESPORTS            BIG
# 207    ESPORTS           1WIN
# 106    ESPORTS     FUT Esports
# 107    ESPORTS     FUT Esports
# 141    ESPORTS         Cloud9
# 135    ESPORTS   Evil Geniuses
# 134    ESPORTS   Evil Geniuses
# 117    ESPORTS     FUT Esports
# 116    ESPORTS     FUT Esports
# 204    ESPORTS           nouns
# 200    ESPORTS           Quest
# 203    ESPORTS           nouns

# %%
#underdog for now
new = fullpdf.merge(pp_lines, on=['Player','Stat','Line'],how='inner').sort_values(by='o_Prob')
new.to_csv(f'bets/bets_{str(today)}.csv')
new= new.round(3)

new = new.merge(dog_lines, on=['Player','Stat'],how='inner',suffixes=('_pp','_dog'))
new['difference'] = ((new['Line_pp'] - new['Line_dog']))/new['Line_pp']
new
# Out:
#                 Player                Stat  Line_pp  o_Prob  u_Prob  \
# 0         Marcus Smart                 PTS     13.5   0.397   0.603
# 1         Marcus Smart             PTS+AST     19.5   0.428   0.572
# 2        Derrick White             PTS+TRB     17.5   0.450   0.550
# 3     Noah Syndergaard  Pitcher Strikeouts      4.0   0.458   0.542
# 4       Patrick Corbin  Pitcher Strikeouts      4.0   0.468   0.532
# 5       Taijuan Walker  Pitcher Strikeouts      4.0   0.468   0.532
# 6         Mitch Keller  Pitcher Strikeouts      7.0   0.470   0.530
# 7         Marcus Smart             PTS+TRB     16.5   0.474   0.526
# 8           Al Horford                 AST      2.5   0.481   0.519
# 9        Derrick White             PTS+AST     16.5   0.483   0.517
# 10  Matthew Liberatore  Pitcher Strikeouts      4.0   0.485   0.515
# 11        Jaylen Brown         PTS+TRB+AST     32.5   0.486   0.514
# 12        Jayson Tatum             PTS+TRB     41.5   0.486   0.514
# 13   Grayson Rodriguez  Pitcher Strikeouts      5.5   0.487   0.513
# 14        Caleb Martin                 PTS     13.5   0.487   0.513
# 15        Hunter Brown  Pitcher Strikeouts      6.0   0.488   0.512
# 16        Jayson Tatum             PTS+AST     36.5   0.489   0.511
# 17        Marcus Smart         PTS+TRB+AST     22.5   0.490   0.510
# 18        Caleb Martin         PTS+TRB+AST     19.5   0.492   0.508
# 19        Marcus Smart                 TRB      3.5   0.492   0.508
# 20       Louie Varland  Pitcher Strikeouts      5.0   0.493   0.507
# 21       Derrick White         PTS+TRB+AST     19.5   0.493   0.507
# 22        Jayson Tatum                 PTS     30.5   0.495   0.505
# 23        Jimmy Butler                 TRB      7.5   0.499   0.501
# 24       Kevin Gausman  Pitcher Strikeouts      8.0   0.500   0.500
# 25        Jimmy Butler             PTS+TRB     36.5   0.501   0.499
# 26       Jared Shuster  Pitcher Strikeouts      4.5   0.501   0.499
# 27         Bam Adebayo             PTS+TRB     26.5   0.503   0.497
# 28        Caleb Martin             PTS+TRB     18.5   0.504   0.496
# 29        Jaylen Brown             PTS+AST     26.5   0.505   0.495
# 30          Al Horford             PTS+TRB     13.5   0.506   0.494
# 31        Jayson Tatum                 TRB     10.5   0.506   0.494
# 32        Jimmy Butler         PTS+TRB+AST     42.5   0.507   0.493
# 33        Jaylen Brown                 PTS     22.5   0.508   0.492
# 34       Derrick White                 PTS     13.5   0.509   0.491
# 35        George Kirby  Pitcher Strikeouts      5.5   0.509   0.491
# 36        Jaylen Brown             PTS+TRB     28.5   0.513   0.487
# 37        Jordan Lyles  Pitcher Strikeouts      3.5   0.513   0.487
# 38       Justin Steele  Pitcher Strikeouts      5.5   0.517   0.483
# 39        Jimmy Butler                 PTS     28.5   0.520   0.480
# 40        Caleb Martin             PTS+AST     14.5   0.521   0.479
# 41      Freddy Peralta  Pitcher Strikeouts      6.5   0.522   0.478
# 42         Bam Adebayo                 PTS     17.5   0.522   0.478
# 43        Jimmy Butler             PTS+AST     34.5   0.523   0.477
# 44        Jaylen Brown                 AST      3.5   0.524   0.476
# 45        Jaylen Brown                 TRB      5.5   0.525   0.475
# 46         Bam Adebayo             PTS+AST     20.5   0.526   0.474
# 47         Bam Adebayo                 TRB      8.5   0.526   0.474
# 48         Bam Adebayo         PTS+TRB+AST     29.5   0.534   0.466
# 49      Connor Seabold  Pitcher Strikeouts      3.0   0.534   0.466
# 50    James Kaprielian  Pitcher Strikeouts      4.0   0.538   0.462
# 51        Shane Bieber  Pitcher Strikeouts      5.0   0.544   0.456
# 52          Al Horford         PTS+TRB+AST     15.5   0.556   0.444
# 53           Max Strus             PTS+TRB     13.5   0.679   0.321
# 54           Max Strus         PTS+TRB+AST     15.5   0.843   0.157
# 55           Max Strus             PTS+AST     12.5   0.898   0.102
#
#     num_books   means Team_pp  League_pp     Date_pp  Line_dog League_dog  \
# 0         1.0  12.724     MIA          7  2023-05-27      13.5        NBA
# 1         1.0  18.872     MIA          7  2023-05-27      19.5        NBA
# 2         3.0  17.148     MIA          7  2023-05-27      17.5        NBA
# 3         1.0   3.987      TB          2  2023-05-26       4.0        MLB
# 4         1.0   4.027      KC          2  2023-05-26       4.0        MLB
# 5         1.0   4.028     ATL          2  2023-05-26       4.0        MLB
# 6         1.0   6.990     SEA          2  2023-05-26       7.0        MLB
# 7         3.0  16.406     MIA          7  2023-05-27      16.5        NBA
# 8         7.0   2.596     MIA          7  2023-05-27       2.5        NBA
# 9         5.0  16.498     MIA          7  2023-05-27      16.5        NBA
# 10        1.0   4.098     CLE          2  2023-05-26       4.0        MLB
# 11        6.0  32.460     MIA          7  2023-05-27      32.5        NBA
# 12        6.0  41.436     MIA          7  2023-05-27      41.5        NBA
# 13       10.0   5.593     TEX          2  2023-05-26       5.5        MLB
# 14        8.0  13.553     BOS          7  2023-05-27      13.5        NBA
# 15        1.0   6.099     OAK          2  2023-05-26       6.0        MLB
# 16        6.0  36.500     MIA          7  2023-05-27      36.5        NBA
# 17        7.0  22.553     MIA          7  2023-05-27      22.5        NBA
# 18        3.0  19.575     BOS          7  2023-05-27      19.5        NBA
# 19        7.0   3.633     MIA          7  2023-05-27       3.5        NBA
# 20        1.0   5.127     TOR          2  2023-05-26       5.0        MLB
# 21        9.0  19.591     MIA          7  2023-05-27      19.5        NBA
# 22        9.0  30.602     MIA          7  2023-05-27      30.5        NBA
# 23        9.0   7.662     BOS          7  2023-05-27       7.5        NBA
# 24        1.0   8.161     MIN          2  2023-05-26       8.0        MLB
# 25        6.0  36.675     BOS          7  2023-05-27      36.5        NBA
# 26       10.0   4.678     PHI          2  2023-05-26       4.5        MLB
# 27        6.0  26.704     BOS          7  2023-05-27      26.5        NBA
# 28        4.0  18.710     BOS          7  2023-05-27      18.5        NBA
# 29        6.0  26.737     MIA          7  2023-05-27      26.5        NBA
# 30        3.0  13.721     MIA          7  2023-05-27      13.5        NBA
# 31        9.0  10.716     MIA          7  2023-05-27      10.5        NBA
# 32        9.0  42.779     BOS          7  2023-05-27      42.5        NBA
# 33        9.0  22.765     MIA          7  2023-05-27      22.5        NBA
# 34        9.0  13.751     MIA          7  2023-05-27      13.5        NBA
# 35       10.0   5.725     PIT          2  2023-05-26       5.5        MLB
# 36        5.0  28.841     MIA          7  2023-05-27      28.5        NBA
# 37       10.0   3.736     WSH          2  2023-05-26       3.5        MLB
# 38       10.0   5.769     CIN          2  2023-05-26       5.5        MLB
# 39        9.0  28.933     BOS          7  2023-05-27      28.5        NBA
# 40        3.0  14.874     BOS          7  2023-05-27      14.5        NBA
# 41       10.0   6.814      SF          2  2023-05-26       6.5        MLB
# 42        6.0  17.905     BOS          7  2023-05-27      17.5        NBA
# 43        5.0  35.014     BOS          7  2023-05-27      34.5        NBA
# 44        9.0   3.790     MIA          7  2023-05-27       3.5        NBA
# 45        9.0   5.820     MIA          7  2023-05-27       5.5        NBA
# 46        4.0  20.961     BOS          7  2023-05-27      21.0        NBA
# 47        9.0   8.864     BOS          7  2023-05-27       8.5        NBA
# 48        4.0  30.136     BOS          7  2023-05-27      29.5        NBA
# 49        1.0   3.285     NYM          2  2023-05-26       3.0        MLB
# 50        1.0   4.326     HOU          2  2023-05-26       4.0        MLB
# 51        1.0   5.379     STL          2  2023-05-26       5.0        MLB
# 52        2.0  16.235     MIA          7  2023-05-27      16.5        NBA
# 53        1.5  15.454     BOS          7  2023-05-27      13.5        NBA
# 54        3.0  19.987     BOS          7  2023-05-27      15.5        NBA
# 55        1.0  17.739     BOS          7  2023-05-27      12.5        NBA
#
#    Team_dog    Date_dog  difference
# 0       BOS  2023-05-27    0.000000
# 1       BOS  2023-05-27    0.000000
# 2       BOS  2023-05-27    0.000000
# 3       LAD  2023-05-26    0.000000
# 4       WSH  2023-05-26    0.000000
# 5       PHI  2023-05-26    0.000000
# 6       PIT  2023-05-26    0.000000
# 7       BOS  2023-05-27    0.000000
# 8       BOS  2023-05-27    0.000000
# 9       BOS  2023-05-27    0.000000
# 10      STL  2023-05-26    0.000000
# 11      BOS  2023-05-27    0.000000
# 12      BOS  2023-05-27    0.000000
# 13      BAL  2023-05-26    0.000000
# 14      MIA  2023-05-27    0.000000
# 15      HOU  2023-05-26    0.000000
# 16      BOS  2023-05-27    0.000000
# 17      BOS  2023-05-27    0.000000
# 18      MIA  2023-05-27    0.000000
# 19      BOS  2023-05-27    0.000000
# 20      MIN  2023-05-26    0.000000
# 21      BOS  2023-05-27    0.000000
# 22      BOS  2023-05-27    0.000000
# 23      MIA  2023-05-27    0.000000
# 24      TOR  2023-05-26    0.000000
# 25      MIA  2023-05-27    0.000000
# 26      ATL  2023-05-26    0.000000
# 27      MIA  2023-05-27    0.000000
# 28      MIA  2023-05-27    0.000000
# 29      BOS  2023-05-27    0.000000
# 30      BOS  2023-05-27    0.000000
# 31      BOS  2023-05-27    0.000000
# 32      MIA  2023-05-27    0.000000
# 33      BOS  2023-05-27    0.000000
# 34      BOS  2023-05-27    0.000000
# 35      SEA  2023-05-26    0.000000
# 36      BOS  2023-05-27    0.000000
# 37       KC  2023-05-26    0.000000
# 38      CHC  2023-05-26    0.000000
# 39      MIA  2023-05-27    0.000000
# 40      MIA  2023-05-27    0.000000
# 41      MIL  2023-05-26    0.000000
# 42      MIA  2023-05-27    0.000000
# 43      MIA  2023-05-27    0.000000
# 44      BOS  2023-05-27    0.000000
# 45      BOS  2023-05-27    0.000000
# 46      MIA  2023-05-27   -0.024390
# 47      MIA  2023-05-27    0.000000
# 48      MIA  2023-05-27    0.000000
# 49      COL  2023-05-26    0.000000
# 50      OAK  2023-05-26    0.000000
# 51      CLE  2023-05-26    0.000000
# 52      BOS  2023-05-27   -0.064516
# 53      MIA  2023-05-27    0.000000
# 54      MIA  2023-05-27    0.000000
# 55      MIA  2023-05-27    0.000000

# %%
new.merge(temp, on=['Player','Stat','Line_pp'],how='inner')
# Out:
#         Player         Stat  Line_pp  o_Prob  u_Prob  num_books   means  \
# 0  Bam Adebayo      PTS+AST     20.5   0.526   0.474        4.0  20.961
# 1   Al Horford  PTS+TRB+AST     15.5   0.556   0.444        2.0  16.235
#
#   Team_pp  League_pp     Date_pp  Line_dog_x League_dog_x Team_dog_x  \
# 0     BOS          7  2023-05-27        21.0          NBA        MIA
# 1     MIA          7  2023-05-27        16.5          NBA        BOS
#
#      Date_dog  difference_x  Line_dog_y  difference_y        Date  \
# 0  2023-05-27     -0.024390        21.0     -0.024390  2023-05-27
# 1  2023-05-27     -0.064516        16.5     -0.064516  2023-05-27
#
#   League_dog_y Team_dog_y
# 0          NBA        MIA
# 1          NBA        BOS

# %%
new.columns
# Out:
# Index(['Player', 'Stat', 'Line_pp', 'o_Prob', 'u_Prob', 'num_books', 'means',
#        'Team_pp', 'League_pp', 'Date_pp', 'Line_dog', 'League_dog', 'Team_dog',
#        'Date_dog', 'difference'],
#       dtype='object')

# %%
new[['Player', 'Stat', 'Line_pp', 'Line_dog', 'o_Prob', 'u_Prob','Date_pp','difference']].tail(20)
# Out:
#               Player                Stat  Line_pp  Line_dog  o_Prob  u_Prob  \
# 36      Jaylen Brown             PTS+TRB     28.5      28.5   0.513   0.487
# 37      Jordan Lyles  Pitcher Strikeouts      3.5       3.5   0.513   0.487
# 38     Justin Steele  Pitcher Strikeouts      5.5       5.5   0.517   0.483
# 39      Jimmy Butler                 PTS     28.5      28.5   0.520   0.480
# 40      Caleb Martin             PTS+AST     14.5      14.5   0.521   0.479
# 41    Freddy Peralta  Pitcher Strikeouts      6.5       6.5   0.522   0.478
# 42       Bam Adebayo                 PTS     17.5      17.5   0.522   0.478
# 43      Jimmy Butler             PTS+AST     34.5      34.5   0.523   0.477
# 44      Jaylen Brown                 AST      3.5       3.5   0.524   0.476
# 45      Jaylen Brown                 TRB      5.5       5.5   0.525   0.475
# 46       Bam Adebayo             PTS+AST     20.5      21.0   0.526   0.474
# 47       Bam Adebayo                 TRB      8.5       8.5   0.526   0.474
# 48       Bam Adebayo         PTS+TRB+AST     29.5      29.5   0.534   0.466
# 49    Connor Seabold  Pitcher Strikeouts      3.0       3.0   0.534   0.466
# 50  James Kaprielian  Pitcher Strikeouts      4.0       4.0   0.538   0.462
# 51      Shane Bieber  Pitcher Strikeouts      5.0       5.0   0.544   0.456
# 52        Al Horford         PTS+TRB+AST     15.5      16.5   0.556   0.444
# 53         Max Strus             PTS+TRB     13.5      13.5   0.679   0.321
# 54         Max Strus         PTS+TRB+AST     15.5      15.5   0.843   0.157
# 55         Max Strus             PTS+AST     12.5      12.5   0.898   0.102
#
#        Date_pp  difference
# 36  2023-05-27    0.000000
# 37  2023-05-26    0.000000
# 38  2023-05-26    0.000000
# 39  2023-05-27    0.000000
# 40  2023-05-27    0.000000
# 41  2023-05-26    0.000000
# 42  2023-05-27    0.000000
# 43  2023-05-27    0.000000
# 44  2023-05-27    0.000000
# 45  2023-05-27    0.000000
# 46  2023-05-27   -0.024390
# 47  2023-05-27    0.000000
# 48  2023-05-27    0.000000
# 49  2023-05-26    0.000000
# 50  2023-05-26    0.000000
# 51  2023-05-26    0.000000
# 52  2023-05-27   -0.064516
# 53  2023-05-27    0.000000
# 54  2023-05-27    0.000000
# 55  2023-05-27    0.000000

# %%
import yagmail
import os

attachment = os.path.abspath(f"bets/bets_{today}.csv")

send = True


if send == True:
    with open(attachment, "rb") as f:
        # send the email with the file object as an attachment

        yag = yagmail.SMTP("sharedwestover@gmail.com", oauth2_file="secrets.json")
        yag.send(subject=f"BETS! {str(today)}",attachments=f)
        
    attachment = os.path.abspath(f"bets/fantasy_bets_{today}.csv")


    with open(attachment, "rb") as f:
        # send the email with the file object as an attachment

        yag = yagmail.SMTP("sharedwestover@gmail.com", oauth2_file="secrets.json")
        yag.send(subject=f"BETS! {str(today)}",attachments=f)

# %%
pp_lines.loc[pp_lines.Player=='Frederik Andersen']
# Out:
# Empty DataFrame
# Columns: [Player, Team, Line, Stat, League, Date]
# Index: []

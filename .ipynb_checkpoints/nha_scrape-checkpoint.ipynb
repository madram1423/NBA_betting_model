# %%
#imports and scraping raw data from site
#df is the actual betting line
#df2 has other info, mostly using to get player id to name dict

import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import datetime as dt
import random
from unidecode import unidecode

# %%
headers = {
    'authority': 'webadmin.nohouseadvantage.com',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'en-US,en;q=0.9',
    'authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJodHRwOlwvXC93ZWJhZG1pbi5ub2hvdXNlYWR2YW50YWdlLmNvbVwvYXBpXC9hdXRoXC9sb2dpbiIsImlhdCI6MTY4MzEzODg4NCwibmJmIjoxNjgzMTM4ODg0LCJqdGkiOiJuNHJDZHNmYXg5bFc3VjJvIiwic3ViIjo3NTE3MiwicHJ2IjoiODdlMGFmMWVmOWZkMTU4MTJmZGVjOTcxNTNhMTRlMGIwNDc1NDZhYSJ9.uqSmJP62xo1m3T7P89rWGjP1fjlX3iGSOeFkQov8GxQ',
    'content-type': 'application/json',
    'origin': 'https://web.nohouseadvantage.com',
    'referer': 'https://web.nohouseadvantage.com/',
    'sec-ch-ua': '"Chromium";v="112", "Google Chrome";v="112", "Not:A-Brand";v="99"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36'
}

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

login_url = 'https://web.nohouseadvantage.com/login'
username = 'sharedwestover@gmail.com'
password = 'Westover30'
payload = {'username': username, 'password': password}
session = requests.Session()
session.headers.update(headers)
session.post(login_url, data=payload)
# Out:
# <Response [200]>

# %%
df2 = pd.json_normalize(df.data)

# %%
df3= pd.json_normalize(df2.iloc[0])
df3
# Out:
#          _id  league        date contestId  type player1_id game_id  \
# 0    1153063  SOCCER  2023-05-03     37572     1   90064801   51868
# 1    1153074  SOCCER  2023-05-03     37572     1   90029981   51868
# 2    1153076  SOCCER  2023-05-03     37572     1   90029326   51868
# 3    1153077  SOCCER  2023-05-03     37572     1   90026703   51868
# 4    1152624  SOCCER  2023-05-03     37561     1   90038701   54418
# ..       ...     ...         ...       ...   ...        ...     ...
# 201  1148235     PGA  2023-05-04     37493     1   40003519     545
# 202  1158641     MMA  2023-05-06     37640     1  140000358    3623
# 203  1158640     MMA  2023-05-06     37640     1  140000349    3642
# 204  1158639     MMA  2023-05-06     37640     1  140000294    3701
# 205  1158638     MMA  2023-05-06     37640     1  140000026    3626
#
#     player1.gameid player1.awayteam          player1.hometeam  \
# 0            51868              WHU                       MNC
# 1            51868              WHU                       MNC
# 2            51868              WHU                       MNC
# 3            51868              WHU                       MNC
# 4            54418              ROM                       MON
# ..             ...              ...                       ...
# 201            545                   Wells Fargo Championship
# 202           3623  CharlesJourdain                KronGracie
# 203           3642   JessicaAndrade               Yan Xiaonan
# 204           3701     GilbertBurns            Belal Muhammad
# 205           3626      HenryCejudo         Aljamain Sterling
#
#       player1.match_date         player1.date player1.injury_status  \
# 0    2023-05-03T15:00:00   05\/03 2:00 PM CDT
# 1    2023-05-03T15:00:00   05\/03 2:00 PM CDT
# 2    2023-05-03T15:00:00   05\/03 2:00 PM CDT
# 3    2023-05-03T15:00:00   05\/03 2:00 PM CDT
# 4    2023-05-03T15:00:00   05\/03 2:00 PM CDT
# ..                   ...                  ...                   ...
# 201  2023-05-04T14:11:00   05\/04 1:11 PM CDT
# 202  2023-05-06T22:00:00   05\/06 9:00 PM CDT
# 203  2023-05-06T22:30:00   05\/06 9:30 PM CDT
# 204  2023-05-06T22:45:00   05\/06 9:45 PM CDT
# 205  2023-05-06T23:00:00  05\/06 10:00 PM CDT
#
#     player1.position player1.season              player1.team  \
# 0                  A              1                       MNC
# 1                  M              1                       MNC
# 2                 GK              1                       MNC
# 3                 GK              1                       WHU
# 4                  A              1                       ROM
# ..               ...            ...                       ...
# 201                G      1st Round  Wells Fargo Championship
# 202                F            297
# 203                F            297
# 204                F            297
# 205                F            297
#
#          player1.name                                      player1.image  \
# 0      Erling Haaland  https:\/\/s3-us-west-2.amazonaws.com\/static.f...
# 1               Rodri  https:\/\/s3-us-west-2.amazonaws.com\/static.f...
# 2             Ederson  https:\/\/s3-us-west-2.amazonaws.com\/static.f...
# 3    Lukasz Fabianski  https:\/\/s3-us-west-2.amazonaws.com\/static.f...
# 4       Tammy Abraham  https:\/\/s3-us-west-2.amazonaws.com\/static.f...
# ..                ...                                                ...
# 201     Akshay Bhatia  https:\/\/s3-us-west-2.amazonaws.com\/static.f...
# 202  Charles Jourdain  https:\/\/webadmin.nohouseadvantage.com\/image...
# 203   Jessica Andrade  https:\/\/webadmin.nohouseadvantage.com\/image...
# 204     Gilbert Burns  https:\/\/webadmin.nohouseadvantage.com\/image...
# 205      Henry Cejudo  https:\/\/webadmin.nohouseadvantage.com\/image...
#
#                                        player1.spreads
# 0    [{'spread': 'shots_on_goal', 'points': '1.5', ...
# 1    [{'spread': 'passes', 'points': '97.5', '_id':...
# 2    [{'spread': 'saves', 'points': '1.5', '_id': 1...
# 3    [{'spread': 'saves', 'points': '4.5', '_id': 1...
# 4    [{'spread': 'shots_on_goal', 'points': '0.5', ...
# ..                                                 ...
# 201  [{'spread': 'birdies', 'points': '3.5', '_id':...
# 202  [{'spread': 'significant_strikes_landed', 'poi...
# 203  [{'spread': 'significant_strikes_landed', 'poi...
# 204  [{'spread': 'significant_strikes_landed', 'poi...
# 205  [{'spread': 'significant_strikes_landed', 'poi...
#
# [206 rows x 19 columns]

# %%
url = 'https://webadmin.nohouseadvantage.com/api/thehousecontest/get-contest'
response = session.get(url,headers=headers)

# %%
soup = BeautifulSoup(response.content, 'html.parser')
# extract data from the soup object using standard BeautifulSoup methods

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Admin | NHA </title>
# <base href="https://webadmin.nohouseadvantage.com/admin/dashboard"/>
# <!-- Tell the browser to be responsive to screen width -->
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="" name="csrf-token"/>
# <link href="https://webadmin.nohouseadvantage.com/image/admin/logo_fav.png" rel="shortcut icon" type="image/png"/>
# <!-- Bootstrap 3.3.7 -->
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap/dist/css/bootstrap.min.css" rel="stylesheet"/>
# <!-- Font Awesome -->
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/font-awesome/css/font-awesome.min.css" rel="stylesheet"/>
# <!-- Ionicons -->
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/Ionicons/css/ionicons.min.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/datatables.net-bs/css/dataTables.bootstrap.min.css" rel="stylesheet"/>
# <!-- Theme style -->
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/dist/css/AdminLTE.min.css" rel="stylesheet"/>
# <!-- iCheck -->
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/plugins/iCheck/square/blue.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap-colorpicker/dist/css/bootstrap-colorpicker.min.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/dist/css/skins/_all-skins.min.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/css/custom.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap-datetimepicker/css/bootstrap-datetimepicker.min.css" rel="stylesheet"/>
# <link href="https://use.fontawesome.com/releases/v5.2.0/css/all.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap-datepicker/dist/css/bootstrap-datepicker.min.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/css/bootstrap-notify.css" rel="stylesheet"/>
# <link href="https://webadmin.nohouseadvantage.com/admin_theme/select2/dist/css/select2.min.css" rel="stylesheet"/>
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
#     <script src="https://oss.maxcdn.com/html5shiv/3.7.3/html5shiv.min.js"></script>
#     <script src="https://oss.maxcdn.com/respond/1.4.2/respond.min.js"></script>
#     <![endif]-->
# <!-- Google Font -->
# <link href="https://fonts.googleapis.com/css?family=Source+Sans+Pro:300,400,600,700,300italic,400italic,600italic" rel="stylesheet"/>
# </head><div style="min-height: 1126px;">
# <!-- Content Header (Page header) -->
# <!-- Main content -->
# <section class="content">
# <div class="error-page">
# <h2 class="headline text-red">500</h2>
# <div class="error-content">
# <h3><i class="fa fa-warning text-red"></i> Oops! Something went wrong.</h3>
# <p>
#                     We will work on fixing that right away.
#                     Meanwhile, you may <a href="../../index.html">return to dashboard</a> or try using the search form.
#                 </p>
# <form class="search-form">
# <div class="input-group">
# <input class="form-control" name="search" placeholder="Search" type="text"/>
# <div class="input-group-btn">
# <button class="btn btn-danger btn-flat" name="submit" type="submit"><i class="fa fa-search"></i>
# </button>
# </div>
# </div>
# <!-- /.input-group -->
# </form>
# </div>
# </div>
# <!-- /.error-page -->
# </section>
# <!-- /.content -->
# </div>
# <div id="divLoading"> </div>
# <footer class="main-footer">
# <div class="pull-right hidden-xs">
# <b>Version</b> 2.1.8
#     </div>
# <strong>©2023 <a href="https://webadmin.nohouseadvantage.com/admin/dashboard">NHA</a>.</strong> All rights
#     reserved.
# </footer>
# <!-- jQuery 3 -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/jquery/dist/jquery.min.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/js/jquery-1.11.2.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/js/jquery-migrate-1.2.1.min.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/js/bootstrap-notify.js"></script>
# <!-- Bootstrap 3.3.7 -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap/dist/js/bootstrap.min.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/select2/dist/js/select2.full.min.js"></script>
# <!-- iCheck -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/plugins/iCheck/icheck.min.js"></script>
# <!-- SlimScroll -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/jquery-slimscroll/jquery.slimscroll.min.js"></script>
# <!-- FastClick -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/fastclick/lib/fastclick.js"></script>
# <!-- CK Editor -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/ckeditor/ckeditor.js"></script>
# <!-- Datatable -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/datatables.net/js/jquery.dataTables.min.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/datatables.net-bs/js/dataTables.bootstrap.min.js"></script>
# <script src="https://cdn.datatables.net/buttons/1.5.2/js/dataTables.buttons.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jszip/3.1.3/jszip.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/pdfmake/0.1.36/pdfmake.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/pdfmake/0.1.36/vfs_fonts.js"></script>
# <script src="https://cdn.datatables.net/buttons/1.5.2/js/buttons.html5.min.js"></script>
# <!-- AdminLTE App -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/dist/js/adminlte.min.js"></script>
# <!-- AdminLTE for demo purposes -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/dist/js/demo.js"></script>
# <!-- Custom JS -->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/jquery/custom.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap-colorpicker/dist/js/bootstrap-colorpicker.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/moment.js/2.13.0/moment.min.js"></script>
# <!--<script src="https://cdnjs.cloudflare.com/ajax/libs/bootstrap-datetimepicker/4.17.37/js/bootstrap-datetimepicker.min.js"></script>-->
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap-datetimepicker/js/bootstrap-datetimepicker.min.js"></script>
# <script src="https://webadmin.nohouseadvantage.com/admin_theme/bootstrap-datepicker/dist/js/bootstrap-datepicker.min.js"></script>
# <script src="https://cdn.jsdelivr.net/jquery.validation/1.16.0/jquery.validate.min.js"></script>
# <script src="https://cdn.jsdelivr.net/jquery.validation/1.16.0/additional-methods.min.js"></script>
# <script>
#     $(function () {
#         var startDate = new Date();
#         var fechaFin = new Date();
#         var FromEndDate = new Date();
#         var ToEndDate = new Date();
#          //Date picker
#         $('#datepicker').datepicker({
#           autoclose: true,
#           format: 'dd-mm-yyyy',
#           //startDate: new Date()
#         }).on('changeDate', function(selected){
#             startDate = new Date(selected.date.valueOf());
#             startDate.setDate(startDate.getDate(new Date(selected.date.valueOf())));
#             $('#datepicker1').datepicker('setStartDate', startDate);
#         });
#
#         $('#datepicker1').datepicker({
#           autoclose: true,
#           format: 'dd-mm-yyyy',
#           //startDate: new Date()
#         }).on('changeDate', function(selected){
#             FromEndDate = new Date(selected.date.valueOf());
#             FromEndDate.setDate(FromEndDate.getDate(new Date(selected.date.valueOf())));
#             $('#datepicker').datepicker('setEndDate', FromEndDate);
#         });
#
#         $('#feedsdatepicker').datepicker({
#           autoclose: true,
#           format: 'yyyy-mm-dd',
#           startDate: new Date()
#         });
#
#         $('#datepicker2').datepicker({
#           autoclose: true,
#           format: 'yyyy-mm-dd',
#            endDate: "today",
#             maxDate: new Date()
#         });
#
#         $('#datetimepicker').datepicker({
#             format: "yyyy-mm-dd",
#             autoclose: true,
#             todayBtn: true,
#            // startDate: '+1d'
#             //startDate: new Date()
#         });
#
#         $('#datetimepicker1').datetimepicker({
#           showTodayButton: true,
#           format: 'YYYY-MM-DD HH:mm',
#           sideBySide: true
#         })
#
#         $('#validationpicker').datepicker({
#             format: "yyyy-mm-dd",
#             autoclose: true,
#             //startDate: '-90d',
#             endDate: new Date()
#         }).on('changeDate', function(selected){
#             startDate = new Date(selected.date.valueOf());
#             startDate.setDate(startDate.getDate(new Date(selected.date.valueOf())));
#             $('#validationpicker1').datepicker('setStartDate', startDate);
#         });
#
#         $('#validationpicker1').datepicker({
#             format: "yyyy-mm-dd",
#             autoclose: true,
#             endDate: new Date(),
#         }).on('changeDate', function(selected){
#             FromEndDate = new Date(selected.date.valueOf());
#             FromEndDate.setDate(FromEndDate.getDate(new Date(selected.date.valueOf())));
#             $('#validationpicker').datepicker('setEndDate', FromEndDate);
#         });
#
#         $(function () {
#             $('[data-toggle="tooltip"]').tooltip()
#         })
#
#
#
# //        .on('dp.change', function(e) {
# //            $('#datetimepicker').data("DateTimePicker").maxDate(e.date)
# //        });
# //
#         $('input').iCheck({
#             checkboxClass: 'icheckbox_square-blue',
#             radioClass: 'iradio_square-blue',
#             increaseArea: '20%' /* optional */
#         });
#         $('.my-colorpicker').colorpicker( {
#             format: 'hex'
#         });
#     });
#
#      function reload_table() {
#         table.ajax.reload(null, false);
#     }
#
# </script>
# <script>
#     $(document).ready(function () {
#         $('.sidebar-menu').tree()
#     })
# </script>
# <style>
#     #divLoading{
#         display : none;
#     }
#     #divLoading.show{
#         display : block;
#         position : fixed;
#         z-index: 100;
#         background-image : url('http://loadinggif.com/images/image-selection/3.gif');
#         background-color:#666;
#         opacity : 0.4;
#         background-repeat : no-repeat;
#         background-position : center;
#         left : 0;
#         bottom : 0;
#         right : 0;
#         top : 0;
#     }
#     #loadinggif.show{
#         left : 50%;
#         top : 50%;
#         position : absolute;
#         z-index : 101;
#         width : 32px;
#         height : 32px;
#         margin-left : -16px;
#         margin-top : -16px;
#     }
#     div.content {
#         width : 1000px;
#         height : 1000px;
#     }
#     .select2-results__option[aria-selected=true] {
#         display: none;
#     }
# </style>
#
# </html>

# %%
all_text = soup.get_text()
print(all_text)
# Out:
# No House Advantage - Daily Fantasy Sports for CASH

# %%
df2 = pd.json_normalize(data,record_path='included')
df2
# Out:
#            type      id                               attributes.image_url  \
# 0    new_player    1535  https://static.prizepicks.com/images/players/n...
# 1     stat_type     281                                                NaN
# 2    new_player   67700  https://static.prizepicks.com/images/players/m...
# 3    new_player   38583  https://s3-us-west-2.amazonaws.com/static.fant...
# 4     stat_type     162                                                NaN
# ..          ...     ...                                                ...
# 460  new_player  127268  https://static.prizepicks.com/images/players/m...
# 461  new_player   54828  https://static.prizepicks.com/images/players/n...
# 462  new_player   37863  https://sport-images.prizepicks.com/2022%20Tea...
# 463   stat_type      16                                                NaN
# 464  new_player   15264  https://sport-images.prizepicks.com/2022%20Tea...
#
#     attributes.league  attributes.league_id attributes.market  \
# 0                 NBA                   7.0            Boston
# 1                 NaN                   NaN               NaN
# 2                 MLB                   2.0           Houston
# 3              NFLSZN                 163.0              None
# 4                 NaN                   NaN               NaN
# ..                ...                   ...               ...
# 460               MLB                   2.0           Houston
# 461             NBA1H                  84.0       Los Angeles
# 462           CRICKET                 162.0              None
# 463               NaN                   NaN               NaN
# 464            NASCAR                   4.0              None
#
#              attributes.name attributes.position attributes.team  \
# 0               Jaylen Brown                 G-F             BOS
# 1          Hitter Strikeouts                 NaN             NaN
# 2             Yordan Alvarez                  OF             HOU
# 3               Najee Harris                  RB             PIT
# 4    1st Inning Runs Allowed                 NaN             NaN
# ..                       ...                 ...             ...
# 460               José Abreu                  IF             HOU
# 461            Anthony Davis                 F-C             LAL
# 462             Rohit Sharma                   B  Mumbai Indians
# 463               Pass Yards                 NaN             NaN
# 464            Ross Chastain                   D   Ross Chastain
#
#     attributes.team_name relationships.league.data.type  \
# 0                Celtics                         league
# 1                    NaN                            NaN
# 2                 Astros                         league
# 3                   None                         league
# 4                    NaN                            NaN
# ..                   ...                            ...
# 460               Astros                         league
# 461               Lakers                         league
# 462                37863                         league
# 463                  NaN                            NaN
# 464                 None                         league
#
#     relationships.league.data.id attributes.lfg_ignored_leagues  \
# 0                              7                            NaN
# 1                            NaN                             []
# 2                              2                            NaN
# 3                            163                            NaN
# 4                            NaN                            [2]
# ..                           ...                            ...
# 460                            2                            NaN
# 461                           84                            NaN
# 462                          162                            NaN
# 463                          NaN                             []
# 464                            4                            NaN
#
#     attributes.active attributes.icon attributes.last_five_games_enabled  \
# 0                 NaN             NaN                                NaN
# 1                 NaN             NaN                                NaN
# 2                 NaN             NaN                                NaN
# 3                 NaN             NaN                                NaN
# 4                 NaN             NaN                                NaN
# ..                ...             ...                                ...
# 460               NaN             NaN                                NaN
# 461               NaN             NaN                                NaN
# 462               NaN             NaN                                NaN
# 463               NaN             NaN                                NaN
# 464               NaN             NaN                                NaN
#
#      attributes.projections_count  attributes.rank  \
# 0                             NaN              NaN
# 1                             NaN              NaN
# 2                             NaN              NaN
# 3                             NaN              NaN
# 4                             NaN              NaN
# ..                            ...              ...
# 460                           NaN              NaN
# 461                           NaN              NaN
# 462                           NaN              NaN
# 463                           NaN              NaN
# 464                           NaN              NaN
#
#     relationships.projection_filters.data
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 460                                   NaN
# 461                                   NaN
# 462                                   NaN
# 463                                   NaN
# 464                                   NaN
#
# [465 rows x 19 columns]

# %%
df2.drop(df2.columns[df2.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
#getting names dict from df2

display(df2.head())
names = df2[['type','id', 'attributes.name']]
names = names.loc[names['type']=='new_player']
names = names[['id','attributes.name']]

name = names['attributes.name'].tolist()
id = names['id'].tolist()

names_dict = {id[i]: name[i] for i in range(len(name))}

names_dict
# Out:
#          type     id                               attributes.image_url  \
# 0  new_player   1535  https://static.prizepicks.com/images/players/n...
# 1   stat_type    281                                                NaN
# 2  new_player  67700  https://static.prizepicks.com/images/players/m...
# 3  new_player  38583  https://s3-us-west-2.amazonaws.com/static.fant...
# 4   stat_type    162                                                NaN
#
#   attributes.league  attributes.league_id attributes.market  \
# 0               NBA                   7.0            Boston
# 1               NaN                   NaN               NaN
# 2               MLB                   2.0           Houston
# 3            NFLSZN                 163.0              None
# 4               NaN                   NaN               NaN
#
#            attributes.name attributes.position attributes.team  \
# 0             Jaylen Brown                 G-F             BOS
# 1        Hitter Strikeouts                 NaN             NaN
# 2           Yordan Alvarez                  OF             HOU
# 3             Najee Harris                  RB             PIT
# 4  1st Inning Runs Allowed                 NaN             NaN
#
#   attributes.team_name relationships.league.data.type  \
# 0              Celtics                         league
# 1                  NaN                            NaN
# 2               Astros                         league
# 3                 None                         league
# 4                  NaN                            NaN
#
#   relationships.league.data.id attributes.lfg_ignored_leagues  \
# 0                            7                            NaN
# 1                          NaN                             []
# 2                            2                            NaN
# 3                          163                            NaN
# 4                          NaN                            [2]
#
#   attributes.active attributes.icon attributes.last_five_games_enabled  \
# 0               NaN             NaN                                NaN
# 1               NaN             NaN                                NaN
# 2               NaN             NaN                                NaN
# 3               NaN             NaN                                NaN
# 4               NaN             NaN                                NaN
#
#    attributes.projections_count  attributes.rank  \
# 0                           NaN              NaN
# 1                           NaN              NaN
# 2                           NaN              NaN
# 3                           NaN              NaN
# 4                           NaN              NaN
#
#   relationships.projection_filters.data
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# {'1535': 'Jaylen Brown',
#  '67700': 'Yordan Alvarez',
#  '38583': 'Najee Harris',
#  '69038': 'Eddie Rosario',
#  '47145': 'Michael Gregoritsch',
#  '68845': 'Austin Nola',
#  '125173': 'Corey Kluber',
#  '67552': 'Jonathan India',
#  '128460': 'Sam Curran',
#  '69867': 'Viktor Tsygankov',
#  '57870': 'Jesper Bratt',
#  '125899': 'Ross Stripling',
#  '10': 'Denny Hamlin',
#  '53676': 'Arteezy',
#  '67744': 'Matt Chapman',
#  '85791': 'Vincent Trocheck',
#  '126821': 'Artemi Panarin + Patrick Kane',
#  '48299': 'Jordan Pickford',
#  '70061': 'Maximilian Eggestein',
#  '70121': 'Maxime Dupé',
#  '30': 'Kevin Harvick',
#  '67584': 'Ian Happ',
#  '140535': 'Domingo Germán + Cal Quantrill',
#  '67818': 'Martín Maldonado',
#  '37839': 'Mitchell Marsh',
#  '46778': 'Iñigo Ruiz De Galarreta',
#  '46894': 'Nemanja Gudelj',
#  '87450': 'Rodrigo Riquelme',
#  '47258': 'Emil Forsberg',
#  '26': 'Chase Elliott',
#  '129105': 'Stephen Curry',
#  '57856': 'Filip Chytil',
#  '55074': 'Jayson Tatum',
#  '46783': 'Jaume Costa',
#  '38588': 'Devonta Smith',
#  '57851': 'Chris Kreider',
#  '45046': 'Paulo Gazzaniga',
#  '64277': 'Nine',
#  '55076': 'Jaylen Brown',
#  '67547': 'Kyle Tucker',
#  '21': 'Kyle Larson',
#  '67555': 'Ronald Acuña Jr.',
#  '71007': 'Thairo Estrada',
#  '139793': 'Sikandar Raza',
#  '1291': 'Nikola Jokic',
#  '48294': 'Ben Godfrey',
#  '67669': 'José Ramírez',
#  '58732': 'Klay Thompson',
#  '25010': 'Goofy',
#  '140386': 'Bijan Robinson',
#  '140533': 'Charlie Morton + Tylor Megill',
#  '46781': 'Pablo Maffeo',
#  '47281': 'Mohamed Simakan',
#  '70115': 'Mikkel Desler',
#  '87090': 'Ondrej Palat',
#  '140529': 'Rafa Mir + Bryan Gil',
#  '55176': 'Devin Booker',
#  '49048': 'Harvey Barnes',
#  '4400': 'Chris Buescher',
#  '46915': 'Kang-in Lee',
#  '63551': 'Graviti',
#  '46903': 'Marko Dmitrović',
#  '47278': 'Lukas Klostermann',
#  '58731': 'Klay Thompson',
#  '57850': 'Mika Zibanejad',
#  '70102': 'Stijn Spierings',
#  '57210': 'Stephen Curry',
#  '62332': 'Hardik Pandya',
#  '16126': 'b0RUP',
#  '49056': 'Çağlar Söyüncü',
#  '15261': 'Bubba Wallace',
#  '125201': 'Kevin Durant',
#  '49044': 'James Maddison',
#  '49057': 'Timothy Castagne',
#  '4405': 'Ryan Preece',
#  '140504': 'Jordan Addison',
#  '127255': 'Sean Murphy',
#  '15371': 'neaLaN',
#  '37865': 'SuryaKumar Yadav',
#  '57849': 'Artemi Panarin',
#  '65768': 'Barclay Goodrow',
#  '129868': 'Jayson Tatum',
#  '140541': 'José Berríos + Taijuan Walker ',
#  '96330': 'Vladimir Tarasenko',
#  '69888': 'Juan Soto',
#  '55177': 'Michael Porter Jr.',
#  '57855': 'Kaapo Kakko',
#  '140220': 'Chris Kreider + Jack Hughes',
#  '69749': 'Ty Gibbs',
#  '87089': 'Erik Haula',
#  '140539': 'Tony Gonsolin + Taijuan Walker',
#  '46822': 'Miguel Gutiérrez',
#  '87421': 'Bruce Brown',
#  '63218': 'aspas',
#  '48292': 'Michael Keane',
#  '4396': 'Daniel Suarez',
#  '67595': 'Jake Cronenworth',
#  '55179': 'Aaron Gordon',
#  '129864': 'LeBron James',
#  '140221': 'Mika Zibanejad + Timo Meier',
#  '53574': 'Vincent Sierro',
#  '127251': 'Christian Arroyo',
#  '47307': 'Kiliann Sildillia',
#  '15': 'Joey Logano',
#  '46422': 'Alex Berenguer',
#  '87324': 'Malcolm Brogdon',
#  '1290': 'Jamal Murray',
#  '140005': 'Atharva Taide',
#  '60514': 'James Harden',
#  '46569': 'Iván Martín',
#  '54823': 'Stephen Curry',
#  '67906': 'Cal Quantrill',
#  '57071': 'CYPHER',
#  '57423': 'LeBron James\t',
#  '37858': 'Liam Livingstone',
#  '48807': 'Kevin Danso',
#  '4401': 'William Byron',
#  '25439': 'Tyrese Maxey',
#  '55080': 'Robert Williams III',
#  '70908': 'Alex Call',
#  '62326': 'Shubman Gill',
#  '16539': 'afro',
#  '46427': 'Nico Williams',
#  '46436': 'Mikel Vesga',
#  '39131': 'Travis Kelce',
#  '127613': 'David Miller',
#  '140537': 'Ross Stripling + Luis Garcia',
#  '125741': 'Pipw',
#  '59488': 'Alexis Lafreniere',
#  '46450': 'Unai Simón',
#  '38728': 'Derrick Henry',
#  '39063': 'Stefon Diggs',
#  '67817': 'Mookie Betts',
#  '37876': 'Tim David',
#  '140528': 'Rafa Mir + Erik Lamela',
#  '48944': 'Adrien Thomasson',
#  '127133': 'Dansby Swanson',
#  '96335': 'Kevin Durant',
#  '70413': 'Vaughn Grissom',
#  '688': 'Stefanos Tsitsipas',
#  '140303': 'Bryce Young',
#  '74759': 'Edmundo Sosa',
#  '94854': 'Iga Swiatek',
#  '140538': 'Luke Weaver + Blake Snell',
#  '39285': 'Lamar Jackson',
#  '8': 'Ryan Blaney',
#  '38719': 'Joe Burrow',
#  '47301': 'Christian Günter',
#  '47276': 'Willi Orbán',
#  '140546': 'Kaapo Kakko + Jack Hughes',
#  '125381': 'Josh Berry',
#  '67501': 'Bo Bichette',
#  '52856': 'Tete',
#  '69035': 'Drew Smyly',
#  '69376': 'Myles Straw',
#  '2023': 'Michael Porter Jr.',
#  '140548': 'Domingo Germán + Luis Garcia',
#  '140266': 'Dennis Hadzikadunic',
#  '64218': 'Garrett Wilson',
#  '55180': 'Deandre Ayton',
#  '69249': 'Amon-Ra St. Brown\t',
#  '37852': 'Rahul Tripathi',
#  '46441': 'Yeray Álvarez',
#  '20': 'Brad Keselowski',
#  '38774': 'DK Metcalf',
#  '127333': 'Manish Pandey',
#  '124354': 'MacKenzie Gore',
#  '128869': 'Derrick White',
#  '38670': 'Jalen Hurts',
#  '70159': 'Jose Barrero',
#  '74057': 'Lois Openda',
#  '39240': 'Nick Chubb',
#  '87404': 'Kentavious Caldwell-Pope',
#  '38581': 'Trevor Lawrence',
#  '68506': 'Tony Gonsolin',
#  '70094': 'Thijs Dallinga',
#  '17134': 'Barbora Krejcikova',
#  '55178': 'Chris Paul',
#  '70113': 'Rasmus Nicolaisen',
#  '67698': 'Steven Kwan',
#  '37845': 'Venkatesh Iyer',
#  '37844': 'Nitish Rana',
#  '3324': 'autimatic',
#  '140527': 'Lois Openda + Adrien Thomasson',
#  '48796': 'Przemysław Frankowski',
#  '46897': 'Jesús Navas',
#  '59341': 'Daniel Iversen',
#  '73945': 'Stuart Fairchild',
#  '59970': 'James Harden',
#  '58496': 'Devin Booker',
#  '74353': 'Santiago Bueno',
#  '55410': 'Al Horford',
#  '38700': 'Jonathan Taylor',
#  '68121': 'José Berríos',
#  '48512': 'Oriol Romeu',
#  '57865': 'Jack Hughes',
#  '1266': 'Jayson Tatum',
#  '61070': 'Vitaliy Mykolenko',
#  '127339': 'Cameron Green',
#  '127338': 'Harry Brook',
#  '48893': 'Wout Faes',
#  '140242': 'Mitch Haniger',
#  '127280': 'Jeimer Candelario',
#  '48284': 'Abdoulaye Doucouré',
#  '57866': 'Dougie Hamilton',
#  '46370': 'Manuel Morlanes',
#  '55411': 'Al Horford',
#  '67546': 'Alex Bregman',
#  '37848': 'Aiden Markram',
#  '15122': 'Farlig',
#  '47289': 'Lucas Höler',
#  '47271': 'Konrad Laimer',
#  '140530': 'Bryan Gil + Erik Lamela',
#  '47309': 'Mark Flekken',
#  '70106': 'Denis Genreau',
#  '37840': 'David Warner',
#  '46444': 'Óscar de Marcos',
#  '46893': 'Óliver Torres',
#  '53682': 'NothingToSay',
#  '127330': 'Narayan Jagadeesan',
#  '140545': 'Chris Kreider + Artemi Panarin',
#  '47286': 'Vincenzo Grifo',
#  '67790': 'Patrick Wisdom',
#  '88267': 'Gorka Guruzeta',
#  '140502': 'Quentin Johnston ',
#  '67732': 'Will Smith',
#  '140543': 'Patrick Kane + Timo Meier',
#  '67590': 'Freddie Freeman',
#  '140531': 'Rodrigo Riquelme + Valentin Castellanos',
#  '53677': 'Abed',
#  '67937': 'Jeff McNeil',
#  '140233': 'Igor Shesterkin + Akira Schmid',
#  '1620': 'Tobias Harris',
#  '20146': 'Iga Swiatek',
#  '87402': 'Kentavious Caldwell-Pope',
#  '140499': 'Jaxon Smith-Njigba',
#  '127617': 'Rinku Singh',
#  '58649': 'Snobling',
#  '127283': 'Masataka Yoshida',
#  '69514': 'Austin Slater',
#  '16969': 'raalz',
#  '62468': 'Thomas',
#  '53510': 'FRANSSON',
#  '48901': 'Predrag Rajković',
#  '68566': 'Blake Snell',
#  '125612': 'Luke Weaver',
#  '55078': 'Marcus Smart',
#  '87323': 'Malcolm Brogdon',
#  '140534': 'Drew Smyly + MacKenzie Gore',
#  '69425': 'Nico Hoerner',
#  '54658': 'Andrew Wiggins',
#  '46881': 'Suso',
#  '48800': 'Deiver Machado',
#  '129828': 'Marcus Smart',
#  '15007': 'Chase Briscoe',
#  '70431': 'Tyler Stephenson',
#  '46423': 'Iñaki Williams',
#  '74618': 'Fernando',
#  '47275': 'Joško Gvardiol',
#  '74946': 'Arnau Martinez',
#  '47098': 'Matthias Ginter',
#  '46448': 'Daniel Vivian',
#  '47337': 'David Raum',
#  '140540': 'Domingo Germán + Corey Kluber',
#  '38584': 'Travis Etienne Jr.',
#  '524': 'rallen',
#  '48220': 'Dwight McNeil',
#  '67572': 'Pete Alonso',
#  '68471': 'Melser',
#  '37849': 'Abhishek Sharma',
#  '69292': 'Domingo Germán',
#  '87434': 'Jamal Murray',
#  '140503': 'Zay Flowers',
#  '125263': 'Patrick Kane',
#  '125778': 'kiyotaka',
#  '67592': 'Manny Machado',
#  '62334': 'Wriddhiman Saha',
#  '62211': 'spooke',
#  '140532': 'Spencer Strider + Denyi Reyes',
#  '64276': 'skiter',
#  '140390': 'Luke Maile',
#  '68517': 'Nelson Velazquez',
#  '54718': 'Robert Williams III',
#  '88640': 'Bruce Brown',
#  '67558': 'Austin Riley',
#  '49045': 'Youri Tielemans',
#  '39180': 'Josh Allen',
#  '140542': 'Tony Gonsolin + Luke Weaver',
#  '39625': 'deko',
#  '67623': 'Anthony Rizzo',
#  '54824': 'LeBron James',
#  '55175': 'Nikola Jokic',
#  '1382': 'Anthony Davis',
#  '96518': "D'Angelo Russell",
#  '96519': "D'Angelo Russell",
#  '55934': 'Austin Reaves',
#  '47856': 'Vedat Muriqi',
#  '94871': 'Jessica Pegula',
#  '48808': 'Jonathan Gradit',
#  '70156': 'Joey Meneses',
#  '139980': 'Fernando Tatis Jr.',
#  '67576': 'Spencer Strider',
#  '129829': 'Jaylen Brown',
#  '67670': 'Amed Rosario',
#  '127337': 'Mayank Agarwal',
#  '39309': 'TRAVIS',
#  '46782': 'Martin Valjent',
#  '64215': 'AJ Brown',
#  '37861': 'Shikhar Dhawan',
#  '15142': 'Brehze',
#  '70058': 'Ritsu Doan',
#  '48798': 'Seko Fofana',
#  '17162': 'Jessica Pegula',
#  '25': 'Kyle Busch',
#  '70998': 'CJ Abrams',
#  '28687': 'hype',
#  '47296': 'Nicolas Höfler',
#  '140526': 'Priyam Garg',
#  '127331': 'Rahmanullah Gurbaz',
#  '48789': 'Florian Sotoca',
#  '129027': 'Al Horford',
#  '67533': 'Nick Castellanos',
#  '54827': 'Andrew Wiggins',
#  '140206': 'Vijay Shankar',
#  '47255': 'Christopher Nkunku',
#  '55125': 'Tobias Harris',
#  '139860': 'Nico Hischier + Jesper Bratt',
#  '38711': 'Justin Jefferson',
#  '37864': 'Ishan Kishan',
#  '15010': 'Christopher Bell',
#  '70092': 'Zakaria Aboukhlal',
#  '55935': 'Austin Reaves',
#  '16553': 'hades',
#  '55127': 'Tyrese Maxey',
#  '47300': 'Philipp Lienhart',
#  '46440': 'Yuri Berchiche',
#  '15819': 'Forester',
#  '57854': 'Jacob Trouba',
#  '39125': 'Davante Adams',
#  '48538': 'Bryan Gil',
#  '38586': "Ja'Marr Chase",
#  '37691': 'Aaron Gordon',
#  '60021': 'Derrick White',
#  '69835': 'RAMZES666',
#  '140085': 'Phil Salt',
#  '125740': 'Xant3r',
#  '733': 'Cameron Norrie',
#  '67585': 'Rafael Devers',
#  '306': 'Taylor Fritz',
#  '67499': 'Vladimir Guerrero Jr.',
#  '67500': 'George Springer',
#  '87321': 'Michael McLeod',
#  '60022': 'Derrick White',
#  '48806': 'Facundo Medina',
#  '48226': 'James Tarkowski',
#  '70978': 'Janis Blaswich',
#  '67614': 'Matt Olson',
#  '54140': 'Chris Paul',
#  '140238': 'Aaron Rodgers',
#  '53837': 'Deandre Ayton',
#  '51083': 'keznit',
#  '1536': 'Marcus Smart',
#  '39139': 'Kirk Cousins',
#  '57868': 'Nico Hischier',
#  '125414': 'Timo Meier',
#  '46899': 'Marcos Acuña',
#  '39078': 'Patrick Mahomes',
#  '39194': 'Tyreek Hill',
#  '46785': 'Antonio Raillo',
#  '22': 'Martin Truex Jr.',
#  '94003': 'shiro',
#  '38718': 'CeeDee Lamb',
#  '59489': "K'Andre Miller",
#  '67573': 'Francisco Lindor',
#  '44835': 'Brice Samba',
#  '38686': "D'Andre Swift",
#  '15837': 'KEi',
#  '67914': 'Luis Garcia',
#  '125306': 'Taijuan Walker',
#  '67532': 'Kyle Schwarber',
#  '15368': 'Tyler Reddick',
#  '39181': 'Dak Prescott',
#  '39142': 'Odell Beckham Jr.',
#  '48721': 'Jean Onana',
#  '38693': 'Justin Herbert',
#  '70111': 'Anthony Rouault',
#  '140378': 'C.J. Stroud',
#  '140547': 'Spencer Strider + MacKenzie Gore',
#  '63219': 'Less',
#  '67767': 'Alex Verdugo',
#  '127268': 'José Abreu',
#  '54828': 'Anthony Davis',
#  '37863': 'Rohit Sharma',
#  '15264': 'Ross Chastain'}

# %%
df.head()
# Out:
#          type       id      attributes.board_time attributes.custom_image  \
# 0  projection  1275535  2023-04-27T20:00:00-04:00                    None
# 1  projection  1279426  2023-04-23T00:00:00-04:00                    None
# 2  projection  1286032  2023-04-30T21:30:00-04:00                    None
# 3  projection  1286036  2023-04-30T21:30:00-04:00                    None
# 4  projection  1286039  2023-04-30T21:30:00-04:00                    None
#
#   attributes.description attributes.end_time attributes.flash_sale_line_score  \
# 0               2023 CAR                None                             None
# 1               2023 ATL                None                             None
# 2        Athletic Bilbao                None                             None
# 3           RCD Mallorca                None                             None
# 4           RCD Mallorca                None                             None
#
#    attributes.is_promo  attributes.line_score attributes.projection_type  ...  \
# 0                False                 3674.5                Single Stat  ...
# 1                False                 1075.5                Single Stat  ...
# 2                False                    0.5                Single Stat  ...
# 3                False                    0.5                Single Stat  ...
# 4                False                    0.5                Single Stat  ...
#
#    relationships.league.data.type  relationships.league.data.id  \
# 0                          league                           163
# 1                          league                           163
# 2                          league                            82
# 3                          league                            82
# 4                          league                            82
#
#   relationships.new_player.data.type relationships.new_player.data.id  \
# 0                         new_player                           140303
# 1                         new_player                           140386
# 2                         new_player                            46370
# 3                         new_player                            46448
# 4                         new_player                            46423
#
#   relationships.projection_type.data.type  \
# 0                         projection_type
# 1                         projection_type
# 2                         projection_type
# 3                         projection_type
# 4                         projection_type
#
#   relationships.projection_type.data.id relationships.stat_type.data.type  \
# 0                                     2                         stat_type
# 1                                     2                         stat_type
# 2                                     2                         stat_type
# 3                                     2                         stat_type
# 4                                     2                         stat_type
#
#    relationships.stat_type.data.id relationships.duration.data.type  \
# 0                               16                              NaN
# 1                               15                              NaN
# 2                               50                              NaN
# 3                               50                              NaN
# 4                              104                              NaN
#
#   relationships.duration.data.id
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 28 columns]

# %%
#viewing all the columns to see what i need

base = df[:-1]
base.loc[15]
# Out:
# type                                                      projection
# id                                                           1280900
# attributes.board_time                      2023-04-26T19:40:00-04:00
# attributes.custom_image                                         None
# attributes.description                                  PHI 1st Half
# attributes.end_time                                             None
# attributes.flash_sale_line_score                                None
# attributes.is_promo                                            False
# attributes.line_score                                           14.5
# attributes.projection_type                               Single Stat
# attributes.rank                                                    1
# attributes.refundable                                           True
# attributes.start_time                      2023-05-01T19:40:00-04:00
# attributes.stat_type                                          Points
# attributes.status                                           pre_game
# attributes.tv_channel                                           None
# attributes.updated_at                      2023-04-30T18:14:12-04:00
# relationships.duration.data                                      NaN
# relationships.league.data.type                                league
# relationships.league.data.id                                      84
# relationships.new_player.data.type                        new_player
# relationships.new_player.data.id                               55074
# relationships.projection_type.data.type              projection_type
# relationships.projection_type.data.id                              2
# relationships.stat_type.data.type                          stat_type
# relationships.stat_type.data.id                                   19
# relationships.duration.data.type                            duration
# relationships.duration.data.id                                    12
# Name: 15, dtype: object

# %%
id[0:5]
# Out:
# ['1535', '67700', '38583', '69038', '47145']

# %%
ids = df['relationships.new_player.data.id'].unique()
print(len(ids))
# Out:
# 394

# %%
#trimming excess columns and adding actual player names

df = base[['attributes.description','attributes.line_score',
        'attributes.stat_type','relationships.new_player.data.id','relationships.league.data.id','attributes.start_time']]

df['Player'] = df['relationships.new_player.data.id'].map(names_dict)
df = df[['Player','attributes.description', 'attributes.line_score', 'attributes.stat_type','relationships.league.data.id','attributes.start_time']]

df = df.rename(columns={"attributes.description": "Team", "attributes.line_score": "Line", 
                        'attributes.stat_type':'Stat','relationships.league.data.id':'League',
                       'attributes.start_time':'Date'})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11644\2042246692.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player'] = df['relationships.new_player.data.id'].map(names_dict)

# %%
df.League.unique()
# Out:
# array(['163', '82', '2', '4', '84', '7', '250', '5', '244', '174', '159',
#        '162', '124', '8'], dtype=object)

# %%
full = df.copy(deep=True)

# %%
#df = df.loc[df.League=='7']
df['Date'] = df['Date'].apply(lambda x: x.split('T')[0])
df['Player'] = df['Player'].apply(lambda x: unidecode(x).replace('_',' '))
df
# Out:
#                              Player             Team    Line             Stat  \
# 0                       Bryce Young         2023 CAR  3674.5       Pass Yards
# 1                    Bijan Robinson         2023 ATL  1075.5       Rush Yards
# 2                   Manuel Morlanes  Athletic Bilbao     0.5            Shots
# 3                     Daniel Vivian     RCD Mallorca     0.5            Shots
# 4                    Inaki Williams     RCD Mallorca     0.5  Shots On Target
# ..                              ...              ...     ...              ...
# 837    Nico Hischier + Jesper Bratt              NYR     5.5    Shots On Goal
# 838       Kaapo Kakko + Jack Hughes           NJ/NYR     0.5            Goals
# 839       Patrick Kane + Timo Meier           NJ/NYR     0.5            Goals
# 840    Nico Hischier + Jesper Bratt              NYR     0.5            Goals
# 841  Chris Kreider + Artemi Panarin               NJ     0.5            Goals
#
#     League        Date
# 0      163  2023-09-07
# 1      163  2023-09-07
# 2       82  2023-05-01
# 3       82  2023-05-01
# 4       82  2023-05-01
# ..     ...         ...
# 837      8  2023-05-01
# 838      8  2023-05-01
# 839      8  2023-05-01
# 840      8  2023-05-01
# 841      8  2023-05-01
#
# [842 rows x 6 columns]

# %%
syntax = {
    'Points': 'PTS',
    'Rebs': 'TRB',
    'Asts': 'AST',
    'Rebounds': 'TRB',
    '3-PT Made': '3P',
    'Assists': 'AST',
    'Turnovers': 'TOV',
    'Blks': 'BLK',
    'Pts': 'PTS',
    'Pts+Asts': 'PTS+AST',
    'Pts+Rebs+Asts':'PTS+TRB+AST',
    'Pts+Rebs':'PTS+TRB',
    'Rebs+Asts':'TRB+AST',
    'Blks+Stls':'BLK+STL',
    'Stls': 'STL',
    'Free Throws Made': 'FT',
    'Blocked Shots': 'BLK',
    'Steals': 'STL',
    'Personal Fouls': 'PF',
    'FG Attempted': 'FGA'
}
df = df.replace(syntax)
df.Stat.unique()
# Out:
# array(['Pass Yards', 'Rush Yards', 'Shots', 'Shots On Target',
#        'Shots Assisted', 'Earned Runs Allowed', 'Pitcher Fantasy Score',
#        'Crosses', 'Walks Allowed', 'Clearances', 'Passes Attempted',
#        'Pitcher Strikeouts', 'Hits+Runs+RBIS', 'Fantasy Score', 'PTS',
#        'Tackles', 'PTS+AST', 'TRB+AST', 'AST', '3P', 'PTS+TRB+AST', 'TRB',
#        'Pitching Outs', 'BLK', 'Hits Allowed', 'PTS+TRB',
#        '1st Inning Runs Allowed', 'Goalie Saves',
#        '1st Inning Hits Allowed', 'Hitter Fantasy Score', 'BLK+STL',
#        'TOV', 'Total Games', 'Break Points Won', '2nd Set - Total Games',
#        '1st Set - Total Games', 'STL', 'Hitter Strikeouts',
#        'MAPS 1-2 Kills', 'MAP 3 Kills', 'Laps Led', 'Fastest Laps', 'FT',
#        'Cars Passed (Net)', 'Total Bases', 'Receiving Yards', 'Runs',
#        'MAP 3 Headshots', 'MAPS 1-2 Headshots', 'Shots On Goal', 'Hits',
#        'Faceoffs Won', 'Goals'], dtype=object)

# %%
len(df)
# Out:
# 842

# %%
df = df[df.Stat != 'Fantasy Score']

# %%
len(df)
# Out:
# 782

# %%
df = df.replace('Fred VanVleet\t','Fred VanVleet')
df = df.replace('Nicolas Claxton','Nic Claxton')
df = df.replace('Robert Williams III','Robert Williams')
df = df.replace('LeBron James\t','LeBron James')
df= df.replace('KJ Martin Jr.','Kenyon Martin Jr.')
df= df.replace('Xavier Tillman','Xavier Tillman Sr.')#xav

# %%
df = df.reset_index(drop=True)

# %%
today= dt.date.today()
df.sample(5)
# Out:
#                Player          Team    Line                Stat League  \
# 513     Ja'Marr Chase      2023 CIN  1325.5     Receiving Yards    163
# 712            Brehze          LDLC    20.0  MAPS 1-2 Headshots    124
# 552  Stuart Fairchild            SD     0.5         Total Bases      2
# 581     Stephen Curry  LAL 1st Half    21.5         PTS+TRB+AST     84
# 710            neaLaN          LDLC     9.0     MAP 3 Headshots    124
#
#            Date
# 513  2023-09-07
# 712  2023-05-01
# 552  2023-05-01
# 581  2023-05-02
# 710  2023-05-01

# %%
f'lines{today.month}_{today.day}'
# Out:
# 'lines5_1'

# %%
nba = df.loc[df.League=='7']
nba.to_csv(f'Lines/lines{today.month}_{today.day}')

# %%
pd.option_context('display.max_columns', 5)
df
# Out:
#                              Player             Team    Line             Stat  \
# 0                       Bryce Young         2023 CAR  3674.5       Pass Yards
# 1                    Bijan Robinson         2023 ATL  1075.5       Rush Yards
# 2                   Manuel Morlanes  Athletic Bilbao     0.5            Shots
# 3                     Daniel Vivian     RCD Mallorca     0.5            Shots
# 4                    Inaki Williams     RCD Mallorca     0.5  Shots On Target
# ..                              ...              ...     ...              ...
# 777    Nico Hischier + Jesper Bratt              NYR     5.5    Shots On Goal
# 778       Kaapo Kakko + Jack Hughes           NJ/NYR     0.5            Goals
# 779       Patrick Kane + Timo Meier           NJ/NYR     0.5            Goals
# 780    Nico Hischier + Jesper Bratt              NYR     0.5            Goals
# 781  Chris Kreider + Artemi Panarin               NJ     0.5            Goals
#
#     League        Date
# 0      163  2023-09-07
# 1      163  2023-09-07
# 2       82  2023-05-01
# 3       82  2023-05-01
# 4       82  2023-05-01
# ..     ...         ...
# 777      8  2023-05-01
# 778      8  2023-05-01
# 779      8  2023-05-01
# 780      8  2023-05-01
# 781      8  2023-05-01
#
# [782 rows x 6 columns]

# %%
df['Date'].max()
# Out:
# '2023-09-07'

# %%
df.to_csv(f'Lines/full_lines{today.month}_{today.day}')

# %%
df.League.unique()
# Out:
# array(['163', '82', '2', '84', '7', '250', '5', '244', '174', '4', '159',
#        '162', '124', '8'], dtype=object)

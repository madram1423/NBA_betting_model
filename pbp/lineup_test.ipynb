# %%
import pandas as pd

# %%
df = pd.read_csv('intermediate.csv',index_col=0)
df.head(10)
# Out:
#     game_id  eventnum  eventmsgtype  eventmsgactiontype  period pctimestring  \
# 0  22300142         2            12                   0       1        12:00
# 1  22300142         4            10                   0       1        12:00
# 2  22300142         7             1                   1       1        11:40
# 3  22300142         9             2                 101       1        11:19
# 4  22300142        10             4                   0       1        11:17
# 5  22300142        11             1                   1       1        11:13
# 6  22300142        13             5                   1       1        10:58
# 7  22300142        15             1                 106       1        10:52
# 8  22300142        17             1                  79       1        10:39
# 9  22300142        19             6                  26       1        10:24
#
#                                      homedescription  \
# 0                                                NaN
# ...
